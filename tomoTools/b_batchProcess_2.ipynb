# %%
# Clear memory
# %reset -f

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import ipywidgets
ipywidgets.Widget.close_all()

import SimpleITK
import datetime
import gc # Garbage collected
import numpy as np
import sys, os
import time
import tifffile
import matplotlib.pyplot as plt
import scipy
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askopenfilenames, askdirectory
import torch
import copy

this_path = os.getcwd()
print(this_path)


import h5py
# import File
from scripts import *
import wrapper_ASTRA
# Out:
# <style>.container { width:90% !important; }</style>
# /global/u2/e/eboigne/tomoTools_als832/tomoTools

# %%
# path_save = '/Documents/nersc_als/2022_wood/'
path_save = '/global/homes/e/eboigne/cfs_als/2022_wood/'

path_in = path_save

# %%
print(torch.version.cuda)
# Out:
# 11.3

# %%
# ===== 21 =======

scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_100425_21_SampleO7_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_100935_21_SampleO7_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_101446_21_SampleO7_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102625_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.0
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102927_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.2
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103229_21_SampleO7_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103532_21_SampleO7_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103832_21_SampleO7_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.53
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104143_21_SampleO7_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104454_21_SampleO7_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.51
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104802_21_SampleO7_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105112_21_SampleO7_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105420_21_SampleO7_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105723_21_SampleO7_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.72
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110021_21_SampleO7_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.93
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110325_21_SampleO7_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110625_21_SampleO7_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110926_21_SampleO7_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.34
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111226_21_SampleO7_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.26
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111544_21_SampleO7_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.8
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111845_21_SampleO7_2xLens_21_cooling_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.15
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112154_21_SampleO7_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.45
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112705_21_SampleO7_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_113214_21_SampleO7_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.85
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174749_24_SampleB2_2xLens_05_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['N_angles_per_half_circle'] = 1313
    scan['COR'] = -17.71
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175049_24_SampleB2_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.715
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175354_24_SampleB2_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175656_24_SampleB2_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.66
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180013_24_SampleB2_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180325_24_SampleB2_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.84
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180627_24_SampleB2_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180929_24_SampleB2_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181233_24_SampleB2_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.8
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181536_24_SampleB2_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181852_24_SampleB2_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182201_24_SampleB2_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.9
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182504_24_SampleB2_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182808_24_SampleB2_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.05
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183113_24_SampleB2_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183424_24_SampleB2_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183729_24_SampleB2_2xLens_21_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184047_24_SampleB2_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.0
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184552_24_SampleB2_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_185100_24_SampleB2_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    path_mask = path_in+'mask_allWhite.tif'

tiles_queue.append(('run24_birch_lowHeat_test2', scans))

# %%
for scan in scans_queue:
    print(scan)

# %%
for scan in scans_queue:
    reconstruct_scan(path_in, scan, path_save = path_save)
# Out:
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5
# 	- 10 dark fields
# 	- 0 white fields
# 	- 385 projections
# 	- Image size: (1396, 2560)
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	- 10 dark fields
# 	- 100 white fields
# 	- 5249 projections
# 	- Image size: (1396, 2560)
# 	Importing dark -- Done
# 	Binning dark data ..... Done
# Processing file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	Importing flat -- Done
# 	Importing projections -- Done
# 	Binning data .............................................. Done
# 	Removing outliers (zingers) for flats  Done
# 	Removing outliers (zingers) for proj .............. Done
# 	Computing transmission -- Done
# 	Computing double normalization -- Done
# 	Writing PMDOF_DN to tif -- Done
# 	Making sinograms -- Done
# 	Doing FBP reconstruction (1/2) --

# %%
for tile in tiles_queue:
    print(tile[0])
    for e in tile[1]:
        print(e)
# Out:
# run24_birch_lowHeat_test2
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'N_angles_per_half_circle': 1313, 'COR': -17.71}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175049_24_SampleB2_2xLens_06_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.715, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}

# %%
new_tiles_queue = []
for tile in tiles_queue:

    name_tile = tile[0]
    new_scan_list = []

    for ind_scan in range(len(tile[1])):
        this_scan = tile[1][ind_scan]
        list_FBPs = sorted([e for e in os.listdir(this_scan['path_proj'][:-3]) if 'FBP' in e])

        this_scan['ind'] = this_scan['path_proj'].split('/')[-1].split('_')[5]

        if len(list_FBPs) > 1:
            this_scan['FBP_folder'] = list_FBPs[0]
            this_scan['ind'] = this_scan['ind']+'a'
            new_scan_list.append(this_scan)

            new_scan = copy.deepcopy(this_scan)
            new_scan['FBP_folder'] = list_FBPs[1]
            new_scan['ind'] = new_scan['ind'][:-1]+'b'
            new_scan_list.append(new_scan)
        else:
            this_scan['FBP_folder'] = list_FBPs[0]
            new_scan_list.append(this_scan)

    new_tile = (name_tile, new_scan_list)
    new_tiles_queue.append(new_tile)

# %%
print(new_tiles_queue[0][1][11])
new_tiles_queue[0] = (new_tiles_queue[0][0], new_tiles_queue[0][1][11:])
# Out:
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10a', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84'}

# %%
for new_tile in new_tiles_queue:
    print(new_tile[0])
    for e in new_tile[1]:
        print(e['ind'], e)
# Out:
# run24_birch_lowHeat_test2
# 10a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10a', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84'}
# 10b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10b', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84_b_180-360_flipped'}
# 11a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11a', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75'}
# 11b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11b', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 12a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12a', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75'}
# 12b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12b', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 13a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}
# 13b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13b', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8_b_180-360_flipped'}
# 14a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14a', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0'}
# 14b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14b', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0_b_180-360_flipped'}
# 15a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15a', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1'}
# 15b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15b', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1_b_180-360_flipped'}
# 16a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16a', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9'}
# 16b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16b', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9_b_180-360_flipped'}
# 17a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17a', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1'}
# 17b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17b', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1_b_180-360_flipped'}
# 18a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18a', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05'}
# 18b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18b', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05_b_180-360_flipped'}
# 19a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19a', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2'}
# 19b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19b', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2_b_180-360_flipped'}
# 20a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20a', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6'}
# 20b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20b', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 21a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21a', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6'}
# 21b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21b', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 22 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625, 'ind': '22', 'FBP_folder': '20220501_184047_24_SampleB2_2xLens_22_post_2625_bin1x2x2_FBP_COR_-19.0_c_averaged_half_circles'}
# 23 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '23', 'FBP_folder': '20220501_184552_24_SampleB2_2xLens_23_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}
# 24 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '24', 'FBP_folder': '20220501_185100_24_SampleB2_2xLens_24_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}

# %%
# Test options
# nb_it = 1
# smoothingSigmas = [1]
# shrinkFactors = [8]
# ind_z_start = 20

# # Real
nb_it = 10
smoothingSigmas = [4, 2, 2, 2, 2, 1, 1]
shrinkFactors =   [8, 8, 4, 4, 2, 2, 1]
ind_z_start = 20

path_tile = path_save
for tile in new_tiles_queue:

    name_tile = tile[0]
    print('\n\n============================== NEW TILE ==============================\n')
    print('Processing tile: '+name_tile)

    print('\n\n============ NEW SCAN ============\n')
    print('Processing scan: '+tile[1][0]['path_proj'].split('/')[-1])
    ind = 0

    # static = import_data(path_tile, tile[1][0])
    # File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').saveTiffStack(static)

    static = File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').readAll()

    print(static.shape)
    moving_reg = static

    for ind_scan in range(1, len(tile[1])):
        scan = tile[1][ind_scan]

        print('\n\n============ NEW SCAN ============\n')
        print('Processing scan: '+scan['path_proj'].split('/')[-1])

        static = moving_reg
        moving = import_data(path_tile, scan)

        folder_out_name = path_tile+name_tile+'/'+scan['ind']+'/'
        moving_reg = run_registration(folder_out_name, static, moving, path_mask, save_str='b', nb_it = nb_it, smoothingSigmas = smoothingSigmas, shrinkFactors = shrinkFactors, ind_z_start=ind_z_start)
        print(folder_out_name)

    print('\n')
    print('\n\n')
# Out:
# ============================== NEW TILE ==============================
#
# Processing tile: run24_birch_lowHeat_test2
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_180325_24_SampleB2_2xLens_10_1313.h5
# (698, 1280, 1280)
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_180325_24_SampleB2_2xLens_10_1313.h5
# Importing data:
# This took 55.9769492149353 s
# Initial cost function: 3.449813554357955e+175
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0004796095718181351 - LearningRate: 340.29657808613865
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.044468203322729785, 0.028742800601174616, 0.0010349634108494411)
# Offset in voxels (X, Y, Z): (-0.1379912980196537, -0.19413404079513402, 0.06104549820731791)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00036889989176464326 - LearningRate: 854.689826401423
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0367756879432636, 0.01287870733959832, -0.00022556854895228556)
# Offset in voxels (X, Y, Z): (-0.0738984523154979, -0.13655980318260588, 0.29589047799134294)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003322691480786023 - LearningRate: 393.10607145540723
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06021319297583286, 0.02691068541289398, 0.00016288139920814812)
# Offset in voxels (X, Y, Z): (-0.1444604518106576, -0.2378889337475731, 0.3493990238009025)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00030406300712198126 - LearningRate: 626.4703839822305
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05379680691843985, 0.017018525547893876, -0.0006176137954438001)
# Offset in voxels (X, Y, Z): (-0.10671490227599018, -0.20046309340459617, 0.46172723320695586)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0002908013841473468 - LearningRate: 477.60799982601816
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06823314601882577, 0.024520124281548972, -0.0005302494829373606)
# Offset in voxels (X, Y, Z): (-0.14838241818252082, -0.262967916775284, 0.5124097353347143)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.000281181657538702 - LearningRate: 639.1385049561101
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06136424035613266, 0.01558686658385381, -0.0012415108190483345)
# Offset in voxels (X, Y, Z): (-0.11590934875541739, -0.22826401168638738, 0.5931843002617097)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00027457489153829385 - LearningRate: 414.42414469980906
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07159910689472736, 0.020998404783318287, -0.0011912110392753327)
# Offset in voxels (X, Y, Z): (-0.14724775314365834, -0.27436106299518137, 0.6213220079992396)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.0002690444601975382 - LearningRate: 652.1138409511282
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06728080726900675, 0.014801952990819593, -0.001762188846200676)
# Offset in voxels (X, Y, Z): (-0.12809236535773824, -0.25434153133094783, 0.6779126998062871)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.0002658269776133489 - LearningRate: 435.0801016606619
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0738678122773122, 0.017845176954195678, -0.0018077037061966668)
# Offset in voxels (X, Y, Z): (-0.14885036489380163, -0.285431456847295, 0.6988046352751921)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002634414513415878 - LearningRate: 638.8268820622994
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07029719206602231, 0.012952699973090056, -0.0022952539175812247)
# Offset in voxels (X, Y, Z): (-0.13574103757833278, -0.27114008169718756, 0.7370937963080615)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.920135259628296 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7961.889649847051, 7960.433662721249, 12649.740279548938, 0.999999999998181, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.00047448007992691263 - LearningRate: 84.6477307869327
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06611564107649842, 0.015136062187576809, -0.002780324130815881)
# Offset in voxels (X, Y, Z): (-0.15021240069940703, -0.2441750469396791, 0.7516764712487001)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00046551109642901977 - LearningRate: 91.65423109553112
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06964021545515564, 0.013479580030059312, -0.0029171958377998755)
# Offset in voxels (X, Y, Z): (-0.1477249916938389, -0.2526771484927032, 0.7589175686100395)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0004648548812687176 - LearningRate: 454.3692076762088
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0759633094318597, 0.01012369936595354, -0.004077535699865279)
# Offset in voxels (X, Y, Z): (-0.15685258784143655, -0.24422687902504728, 0.8020277241340281)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00046123768620570313 - LearningRate: 49.66721528522322
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07849499126738509, 0.008935738577696788, -0.004100637248557934)
# Offset in voxels (X, Y, Z): (-0.15400749504827327, -0.2525007241851316, 0.8031051701435161)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00046053858118608377 - LearningRate: 67.69900916864458
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08020124909630717, 0.008016760414145296, -0.004210153706042485)
# Offset in voxels (X, Y, Z): (-0.15323879501038978, -0.2557310524424476, 0.8061113557141077)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00046043793704546424 - LearningRate: 335.6129312171083
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08539338621478135, 0.004818388879193335, -0.0048907090885137216)
# Offset in voxels (X, Y, Z): (-0.15536882798175894, -0.2569832645422949, 0.8230874055852937)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00045935325827714784 - LearningRate: 1496.4914472464927
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10559724925978556, -0.008302927576580436, -0.007787539461761444)
# Offset in voxels (X, Y, Z): (-0.16710959415663307, -0.25792297277966414, 0.8780071200575862)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00045771172740842204 - LearningRate: 101.09915502350036
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.1066574604559858, -0.009881718202506919, -0.007917483950815984)
# Offset in voxels (X, Y, Z): (-0.16390873627408933, -0.2587243116726225, 0.876891774992413)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00045758067167548424 - LearningRate: 135.29162580523
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10747483174183269, -0.010465126156396443, -0.008137021621914053)
# Offset in voxels (X, Y, Z): (-0.16662096859100525, -0.25702451452286385, 0.8759137765189672)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0004575295552027356 - LearningRate: 173.92885790380063
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10902544462947075, -0.012400728627333471, -0.008378298180640528)
# Offset in voxels (X, Y, Z): (-0.16457955292300966, -0.2572041099555826, 0.8744160244938388)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 4.707000494003296 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32830.57745480995, 32824.726459245016, 51241.07520805592, 1.0000000000095497, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0009786012829981847 - LearningRate: 119.90833821960426
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0947131791344712, -0.01190377808920865, -0.00905169876293242)
# Offset in voxels (X, Y, Z): (-0.3361569116384252, -0.36520193084481606, 1.7917162329496261)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008518252478789725 - LearningRate: 49.44331205894079
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0958102073872922, -0.01208284538812023, -0.009068524642618314)
# Offset in voxels (X, Y, Z): (-0.3361429538052407, -0.37086994052545497, 1.7937304281282935)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008516530375063696 - LearningRate: 56.75189396971286
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09676990228754476, -0.012269216562931203, -0.009098434014502629)
# Offset in voxels (X, Y, Z): (-0.33626284698720543, -0.37454827920583217, 1.7966101060929929)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 6.291234016418457 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33705.84854019229, 33699.7191676031, 51233.5120765288, 1.0000000000095497, 1.0000000000038654, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.000852508833585307 - LearningRate: 667.465410896624
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10091291304871988, -0.01352008247947104, -0.009706397763455294)
# Offset in voxels (X, Y, Z): (-0.34466668582624094, -0.35254035674281303, 1.8438790434750008)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.000848622717513644 - LearningRate: 58.997661514651746
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10263629093872098, -0.013930594853239152, -0.009700940109569114)
# Offset in voxels (X, Y, Z): (-0.3426768737868548, -0.3634648234859412, 1.844119553908529)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008479088837857851 - LearningRate: 18.32289312185867
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10296755540095079, -0.014014087838265792, -0.00970685265535908)
# Offset in voxels (X, Y, Z): (-0.34243203912346065, -0.36501719670872906, 1.8445856273575394)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 6.86533522605896 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139169.4006322852, 139139.84049553736, 206217.64354085404, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0018150373072877795 - LearningRate: 200.36287376627686
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09105597362119718, -0.014265750911214044, -0.010282808826374078)
# Offset in voxels (X, Y, Z): (-0.67813008354489, -0.4983525273267698, 3.7576380170645924)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.001631293547221626 - LearningRate: 199.04492528732516
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09290021462850118, -0.014270237767488808, -0.010403070485948835)
# Offset in voxels (X, Y, Z): (-0.6781310846175619, -0.5124647120285273, 3.7684855500509977)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0016306531942677077 - LearningRate: 986.7507905936902
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09796228584439108, -0.014125521119612083, -0.011127948796402385)
# Offset in voxels (X, Y, Z): (-0.6801221406082151, -0.5113667894391248, 3.835354175080536)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0016251835792613655 - LearningRate: 1216.6265603048855
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10482026533603803, -0.014002579066545718, -0.011943042283417228)
# Offset in voxels (X, Y, Z): (-0.6802709402966761, -0.5309258798117177, 3.89480028157881)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0016234124504129416 - LearningRate: 383.9610385646201
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10461454238723991, -0.013773433084594115, -0.01226404602351547)
# Offset in voxels (X, Y, Z): (-0.6828445905068492, -0.49812820237528327, 3.916834185651798)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0016198821568128784 - LearningRate: 93.90349943345049
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10545243052763531, -0.013792056360686419, -0.012310597308382597)
# Offset in voxels (X, Y, Z): (-0.6822906948466144, -0.5061480201219799, 3.9182603090021737)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.001619650964827798 - LearningRate: 76.35127358929044
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.1059457920720501, -0.013791141230301068, -0.01235476766879298)
# Offset in voxels (X, Y, Z): (-0.6820868929146031, -0.509358181981185, 3.920113531709618)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 84.91554498672485 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143070.42842518422, 143039.80799563756, 206212.24372943875, 0.999999999998181, 1.0000000000209184, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.004163572110289619 - LearningRate: 121.50547996799943
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0999210520774611, -0.013931353631637517, -0.012906590084116754)
# Offset in voxels (X, Y, Z): (-0.66395340469646, -0.38236746380531084, 3.956133050288797)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0040308779429044355 - LearningRate: 20.125131379715782
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.10040144632030581, -0.013782376932079059, -0.012943776686107938)
# Offset in voxels (X, Y, Z): (-0.6641769694108256, -0.3868792015758208, 3.9560947282711783)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 27.727340698242188 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (589972.6070171444, 589844.084608039, 827351.1010377387, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.014518644101601037 - LearningRate: 204.39108140866864
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09651910534709802, -0.01399591501884959, -0.013870242549534914)
# Offset in voxels (X, Y, Z): (-1.2266722614111072, -0.5427707572045917, 7.980302187109321)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.014310189845564102 - LearningRate: 173.22638096221775
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0999503934435175, -0.011535324635516415, -0.014293887913298331)
# Offset in voxels (X, Y, Z): (-1.2311442199627622, -0.5761882344604323, 7.983259526608826)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 2 - Cost function: 0.014304899019554451 - LearningRate: 858.7572283966023
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.11039704976229023, -0.001663855228600543, -0.016749922244886344)
# Offset in voxels (X, Y, Z): (-1.177084343031599, -0.5234766982690352, 8.044539914179209)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 3 - Cost function: 0.014253699452130545 - LearningRate: 895.316643503013
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.12219035180625222, 0.008448353951905125, -0.019167767324449348)
# Offset in voxels (X, Y, Z): (-1.1324841271917803, -0.5276157911259867, 8.073820641827647)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 4 - Cost function: 0.01424226952032759 - LearningRate: 313.3936571739822
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.12337463010654193, 0.011417631695735753, -0.020171098646722722)
# Offset in voxels (X, Y, Z): (-1.1030005057326155, -0.43773500688219136, 8.09938530364027)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 5 - Cost function: 0.01421734052900682 - LearningRate: 87.13827322777023
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.12483751535663107, 0.012398647330484718, -0.020373915243084257)
# Offset in voxels (X, Y, Z): (-1.1008902841721604, -0.452476745967986, 8.097094025068406)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 579.3982746601105 s
# Applying transform to volume, took 4.232253789901733 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.12483751535663107, 0.012398647330484718, -0.020373915243084257)
# Offset in voxels (X, Y, Z): (-1.1008902841721604, -0.452476745967986, 8.097094025068406)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 777.672947883606 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/10b/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_180627_24_SampleB2_2xLens_11_1313.h5
# Importing data:
# This took 27.773824214935303 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005872537167559292 - LearningRate: 298.0419622575039
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.057094543223055336, 0.030708063585478538, -0.0028419914162454898)
# Offset in voxels (X, Y, Z): (-0.13772800875726976, 0.2740569028913165, 0.13987018647709432)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0003613902161455777 - LearningRate: 1477.521426196411
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.011909200826739845, 0.023655773110609277, -0.0023089916357771877)
# Offset in voxels (X, Y, Z): (-0.11071683344632541, 0.11171874537302073, 0.47910071896608314)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003063882465902387 - LearningRate: 324.2275747027673
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0295497507175264, 0.03192100218613939, -0.0032488586231256603)
# Offset in voxels (X, Y, Z): (-0.14901954360100253, 0.19742391465929726, 0.5420137604687022)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.0002843296538280422 - LearningRate: 1323.5096931770229
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.007562482669144954, 0.027008996804484375, -0.0029591461476292285)
# Offset in voxels (X, Y, Z): (-0.1345009914588194, 0.11141268843364951, 0.6911515086891683)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0002726663618858456 - LearningRate: 325.2543843109994
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.017667610519695214, 0.031042383536052553, -0.00349248701540474)
# Offset in voxels (X, Y, Z): (-0.1543802371523124, 0.15905142746092588, 0.7258521194778751)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00026590630779400296 - LearningRate: 1265.7760266235055
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.006778877800387031, 0.02759032431548384, -0.003381584743798442)
# Offset in voxels (X, Y, Z): (-0.14745836290298506, 0.11166434635438156, 0.8021456018603019)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00026253827945395345 - LearningRate: 322.5725478963192
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.012501535133090892, 0.029381901474778014, -0.003682327231067311)
# Offset in voxels (X, Y, Z): (-0.15755888944638796, 0.13736084302705637, 0.8212524820336176)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.0002606078430174775 - LearningRate: 1482.7846237796848
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0069534019416805995, 0.026410460536508973, -0.0036885192207602073)
# Offset in voxels (X, Y, Z): (-0.1548371011348157, 0.10787834898731147, 0.8714712064136165)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00025937147637821974 - LearningRate: 293.81962750086973
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010420609924560358, 0.027119449610025995, -0.003862683796622311)
# Offset in voxels (X, Y, Z): (-0.16002275331483298, 0.12227792583404906, 0.8808121080266373)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002587812149874849 - LearningRate: 1456.5895076697482
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010209889353258445, 0.02506720464059821, -0.003982725831805896)
# Offset in voxels (X, Y, Z): (-0.16139419485965445, 0.11318328149064052, 0.9070809561976197)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.3502516746521 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7963.251849770551, 7960.433662721145, 12644.357408785625, 1.0000000000038654, 1.0000000000038654, 1.0000000000038654)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.00047739888125132547 - LearningRate: 76.14513996854726
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0012449968908668043, 0.025099679295471095, -0.003636993364267078)
# Offset in voxels (X, Y, Z): (-0.16466728274660247, 0.06541192357353508, 0.8988579619169927)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00045710790132345223 - LearningRate: 35.877783487755025
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0022271279310657585, 0.02485699102412226, -0.0036799558420786845)
# Offset in voxels (X, Y, Z): (-0.16463818737540842, 0.06724850911273555, 0.900805063190235)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00045705165061245945 - LearningRate: 63.50881677408311
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0034939844501273463, 0.024460079959363532, -0.0037369106663443447)
# Offset in voxels (X, Y, Z): (-0.16476203330067235, 0.06828878059438581, 0.9036486420884864)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 1.4193415641784668 s
# Initial cost function: 0.006712498572513522
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32836.341632820586, 32824.726459244725, 51208.58738424998, 1.0000000000038654, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0009474110477709748 - LearningRate: 120.49900890667914
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.007806452206811499, 0.023655396074667184, -0.0033535976894736343)
# Offset in voxels (X, Y, Z): (-0.3277764561033925, 0.017903472032706216, 1.7960068584054656)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008735092956461565 - LearningRate: 289.96373361352283
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.004211000965252955, 0.02287366844762973, -0.0035838150559784907)
# Offset in voxels (X, Y, Z): (-0.33077723683776217, 0.028284408615132872, 1.8374039219046001)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.000870829324536114 - LearningRate: 281.884172008781
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.005936145487824491, 0.021856185488388927, -0.0035883187052029707)
# Offset in voxels (X, Y, Z): (-0.33121202985547626, -0.012823082118811786, 1.861421170473309)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008657219210962231 - LearningRate: 103.794625218091
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.003420766754623789, 0.021681861891594375, -0.0037034700908710116)
# Offset in voxels (X, Y, Z): (-0.33271829190016766, 0.002040214539196899, 1.875976517613941)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0008642595569079767 - LearningRate: 514.5543316187673
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0003927541256668565, 0.020308080141759513, -0.003935120237031412)
# Offset in voxels (X, Y, Z): (-0.33596307138052384, -0.007782020206570541, 1.9269694949613532)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0008598573827839434 - LearningRate: 667.8952782432239
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.002505078937451628, 0.018534631315029082, -0.004064855420668794)
# Offset in voxels (X, Y, Z): (-0.338502189818287, -0.05036293863849135, 1.9727697590769993)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0008555564848087206 - LearningRate: 75.87431895934543
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004620691540396334, 0.018438249510430837, -0.004142779132805482)
# Offset in voxels (X, Y, Z): (-0.33932150291133584, -0.03743433401874801, 1.9804294412364207)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0008543689992453389 - LearningRate: 67.53547605763593
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.005577723738202154, 0.01830999392297696, -0.004176790427072349)
# Offset in voxels (X, Y, Z): (-0.339730011456447, -0.03481882233056068, 1.9851021094123418)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0008542749533398738 - LearningRate: 334.8022276719509
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.009052764896386564, 0.01762270589493152, -0.004295507284201222)
# Offset in voxels (X, Y, Z): (-0.341318087025928, -0.034058104848803894, 2.004981943520671)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0008538210382113423 - LearningRate: 412.79853689285045
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010369694812168475, 0.016678274614592807, -0.004317550952499587)
# Offset in voxels (X, Y, Z): (-0.3421402065273447, -0.061680883357295366, 2.0199916767695827)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 18.21652102470398 s
# Initial cost function: 6.91659254133963e-310
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33708.1039952963, 33699.71916760374, 51202.11044245144, 0.999999999998181, 0.9999999999981823, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.000851545444552795 - LearningRate: 60.955603978053574
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.011674123789624133, 0.016526592739922272, -0.00435825389995007)
# Offset in voxels (X, Y, Z): (-0.34190884534083105, -0.05529611380521944, 2.0241440068858565)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008512211426607922 - LearningRate: 46.164983726401076
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.012313266592844409, 0.016428167990162314, -0.004377130108540952)
# Offset in voxels (X, Y, Z): (-0.3419083212086988, -0.05362280989206087, 2.0265142522549557)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 4.5500476360321045 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139174.82049674942, 139139.84049553107, 206086.64735391663, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.001742101030901337 - LearningRate: 204.02192410907276
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0008890214291669824, 0.015689049589900004, -0.004082722496005217)
# Offset in voxels (X, Y, Z): (-0.6763517007632763, -0.3175652123225913, 4.024441001351834)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0015989850484578378 - LearningRate: 234.1799146991948
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.002111990863967264, 0.015603792033614441, -0.004182036215226049)
# Offset in voxels (X, Y, Z): (-0.6789175740856968, -0.3033475744926624, 4.048744161196215)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0015977157192964904 - LearningRate: 1160.929954064536
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0016853789743123166, 0.014615403950422101, -0.004457631846728152)
# Offset in voxels (X, Y, Z): (-0.681962457818178, -0.3497054424131519, 4.137719711600074)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0015875410146709732 - LearningRate: 134.11236727545264
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.002602888438209953, 0.014607180141022988, -0.004512465401234835)
# Offset in voxels (X, Y, Z): (-0.6836568880025956, -0.3383561614281501, 4.149076012819765)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0015869020861990794 - LearningRate: 528.9756368247827
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004103108525400701, 0.014362952774459254, -0.004659472993623908)
# Offset in voxels (X, Y, Z): (-0.6867955978757734, -0.3315510011611419, 4.184322089238097)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0015859477142064077 - LearningRate: 630.9422248162632
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0030625415764427453, 0.013812076423793502, -0.004734240144910317)
# Offset in voxels (X, Y, Z): (-0.6857782958392389, -0.3746113154136132, 4.210481115905522)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.001582014967715864 - LearningRate: 113.55277279672367
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004014573573111898, 0.013830730280100761, -0.0047813103133603945)
# Offset in voxels (X, Y, Z): (-0.6873778231106049, -0.36214627484565626, 4.2189635478963)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0015813380184180764 - LearningRate: 107.97162253109093
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004471250669415865, 0.013802932283924539, -0.0048116088708045875)
# Offset in voxels (X, Y, Z): (-0.6881464041651458, -0.35831156426876964, 4.225087511207166)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 98.0018527507782 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143070.7438046274, 143039.8079956409, 206093.66474840752, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.004320400142950839 - LearningRate: 133.58739135129846
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.002364467632134812, 0.013124771352146103, -0.00477737893225203)
# Offset in voxels (X, Y, Z): (-0.6730525836671046, -0.48236830261521324, 4.212827078641153)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.004199492941241013 - LearningRate: 23.212424267200248
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0019220548891202287, 0.013227269779704974, -0.004812973766285597)
# Offset in voxels (X, Y, Z): (-0.6740135321078238, -0.4757974111323162, 4.216864948663185)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 2 - Cost function: 0.004199065935400935 - LearningRate: 7.020346955310384
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0018174956599486584, 0.013253900238143705, -0.004822957411144334)
# Offset in voxels (X, Y, Z): (-0.6742325307169931, -0.4743161346391416, 4.217966197825718)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 39.82591986656189 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (589969.0390727962, 589844.084608049, 826971.2545178927, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.015916469408465347 - LearningRate: 475.6047075952122
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.008952829360424084, 0.013757107767349735, -0.006386800741477434)
# Offset in voxels (X, Y, Z): (-1.3188473078472691, -1.273224512900231, 8.463548611740428)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.015480720789805818 - LearningRate: 396.82961010603515
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004859698646459706, 0.016088632798265633, -0.007816282840650795)
# Offset in voxels (X, Y, Z): (-1.3563441077389136, -0.8690644445905154, 8.627689949103337)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 228.50428462028503 s
# Applying transform to volume, took 4.09586238861084 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.004859698646459706, 0.016088632798265633, -0.007816282840650795)
# Offset in voxels (X, Y, Z): (-1.3563441077389136, -0.8690644445905154, 8.627689949103337)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 457.0503489971161 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/11a/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_180627_24_SampleB2_2xLens_11_1313.h5
# Importing data:
# This took 32.88412618637085 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.000503892481695192 - LearningRate: 328.4919873394647
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.043817019743013275, 0.038648326005062454, 0.0009818969973191568)
# Offset in voxels (X, Y, Z): (-0.18166006697739545, -0.1902067088617894, 0.062026279942329315)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0003651146058347941 - LearningRate: 1013.4453814103988
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.041125096709289315, 0.01936434060399383, -0.00014832823439440897)
# Offset in voxels (X, Y, Z): (-0.09774146089359789, -0.14652677557853977, 0.35040059299580384)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003195775364194675 - LearningRate: 366.1303626471579
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0633109561928896, 0.03812608218374286, 0.00024262617308578002)
# Offset in voxels (X, Y, Z): (-0.18781089127116213, -0.2420052532704437, 0.3983141175656676)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00028735140090198157 - LearningRate: 760.8923200927454
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05937488992142673, 0.02645788536410704, -0.0004391778478386209)
# Offset in voxels (X, Y, Z): (-0.1397815380547776, -0.21265392590401783, 0.5315187648883823)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00027412969959259074 - LearningRate: 424.76098710847936
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07271261378364817, 0.036845590663335884, -0.00029783046980914375)
# Offset in voxels (X, Y, Z): (-0.19189054088279464, -0.27023846715561173, 0.5730794253085333)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.0002634474763826232 - LearningRate: 618.3987710588472
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0684339302533506, 0.028354368358579605, -0.0007963037671738219)
# Offset in voxels (X, Y, Z): (-0.15819638629299648, -0.24671470054007483, 0.6473958231767659)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.0002566265197263536 - LearningRate: 460.2115003716199
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07725337228556327, 0.03476956319433148, -0.0007652739049957342)
# Offset in voxels (X, Y, Z): (-0.1925106169589939, -0.2857063613975233, 0.6800463404412503)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00025196975335104393 - LearningRate: 576.6736950328267
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07369106613894054, 0.028467217314615826, -0.0011567306586139593)
# Offset in voxels (X, Y, Z): (-0.1690101261841006, -0.26854114661626655, 0.7285711891677943)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00024899797019866965 - LearningRate: 471.78096741564406
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07949811766687064, 0.03243654421248002, -0.0011873985535302454)
# Offset in voxels (X, Y, Z): (-0.1922860187005145, -0.29554813845568767, 0.7523396554759988)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002468351717567568 - LearningRate: 591.1709583659908
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07656875933640446, 0.027567560333308812, -0.0015263756766524979)
# Offset in voxels (X, Y, Z): (-0.17580655891792746, -0.28332794114094734, 0.7872210561076102)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.285722970962524 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7963.533051096208, 7960.433662721218, 12652.080909715836, 1.0000000000038654, 1.0000000000038654, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0004667220135851842 - LearningRate: 81.27263855678284
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07183008420700757, 0.030616901441260398, -0.0020172732573606107)
# Offset in voxels (X, Y, Z): (-0.19302674279734097, -0.25284852388196877, 0.801336047246472)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00045524173913131697 - LearningRate: 89.00938178954064
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0753211224796659, 0.02924173493780408, -0.0021213432813977813)
# Offset in voxels (X, Y, Z): (-0.19054627357706883, -0.26016443862633776, 0.8077840749156132)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00045472150397572026 - LearningRate: 441.257558937011
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08310544229576665, 0.02687203536087035, -0.0030635223356298)
# Offset in voxels (X, Y, Z): (-0.19802169232852654, -0.2532285253139803, 0.845850876867759)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 3 - Cost function: 0.0004513343075488331 - LearningRate: 46.01665889584608
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08519702478295096, 0.025992238051754536, -0.0030846209813263745)
# Offset in voxels (X, Y, Z): (-0.1958373447507349, -0.25904791840040803, 0.8470600525762332)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0004509785077185819 - LearningRate: 66.99448907288149
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0870191153718277, 0.02523975379913361, -0.0031716796993772737)
# Offset in voxels (X, Y, Z): (-0.19501255107724547, -0.26188235122750003, 0.8498670344272766)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00045089205184384946 - LearningRate: 332.1203239050663
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.09309839514672404, 0.022804992633251947, -0.0037318857682057797)
# Offset in voxels (X, Y, Z): (-0.196635198607595, -0.26260709954019934, 0.8656275182561092)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 6 - Cost function: 0.0004498735365545071 - LearningRate: 1572.4287023228226
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.117908323052022, 0.012671430524724055, -0.006300302501310288)
# Offset in voxels (X, Y, Z): (-0.20819187134276188, -0.25745446117858317, 0.9208924009049722)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 7 - Cost function: 0.0004479947297844812 - LearningRate: 38.710696957718255
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# ...
# Offset in voxels (X, Y, Z): (-0.38545776806472476, 0.005102182757745268, 0.10148245282831525)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0004379267429834705 - LearningRate: 1465.991998817407
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.034262087665180206, 0.05562693454980695, -0.0016965611302450533)
# Offset in voxels (X, Y, Z): (-0.2677470651989186, -0.08587191846799044, 0.5771616121470279)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003358099770646747 - LearningRate: 327.32514249402504
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.03575991520454699, 0.08364447392665678, -0.0021834739545746164)
# Offset in voxels (X, Y, Z): (-0.39985940745205595, -0.08756898825882807, 0.6318236346621876)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00029940633188611695 - LearningRate: 1100.0349703267937
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.046695606646733376, 0.06567510035878323, -0.0025612726411535177)
# Offset in voxels (X, Y, Z): (-0.32893754016232724, -0.12341517399015912, 0.8061527958305339)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00028158800290261276 - LearningRate: 336.1099835420398
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.047482688513428545, 0.08054306514707567, -0.0028824289821462183)
# Offset in voxels (X, Y, Z): (-0.4011836969072729, -0.1257544140273872, 0.8388733463524112)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.000270844373291793 - LearningRate: 1065.5660672253111
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.052480028821004054, 0.06886183212994258, -0.003266154980904868)
# Offset in voxels (X, Y, Z): (-0.36033724832412184, -0.1464628188923649, 0.9375900915702966)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.0002649099254677275 - LearningRate: 341.6415978184534
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05270254987215003, 0.0771546796429498, -0.0035055255756882534)
# Offset in voxels (X, Y, Z): (-0.40269062815691337, -0.14854348053429844, 0.9573366302657954)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00026128475720685893 - LearningRate: 1036.035811075561
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05447791300423308, 0.06908004224592909, -0.0038854828141416573)
# Offset in voxels (X, Y, Z): (-0.37872089790464486, -0.16094915316661373, 1.0145788921643526)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00025923168317345245 - LearningRate: 345.80330242052577
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.054314375479692194, 0.07365530367930188, -0.004080019189583277)
# Offset in voxels (X, Y, Z): (-0.4041498441825461, -0.16253770403131887, 1.0266396901253396)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002579532375048522 - LearningRate: 1001.0158388092095
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05438608723522273, 0.06781102811776735, -0.004449403699255147)
# Offset in voxels (X, Y, Z): (-0.3901629195991948, -0.1700501958944351, 1.0600745393334647)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.2541422843933105 s
# Initial cost function: 0.03136095346036427
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7968.061461275262, 7960.433662721158, 12654.103346022792, 0.999999999998181, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005036093036925184 - LearningRate: 78.05251555232229
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0476050024160817, 0.07129545785795471, -0.005005029123711315)
# Offset in voxels (X, Y, Z): (-0.4093319437378216, -0.13164505657592657, 1.0712577482866987)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00048690309963626545 - LearningRate: 21.944695884240083
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04833404669674911, 0.07095070551305205, -0.005029537097765442)
# Offset in voxels (X, Y, Z): (-0.4087321611929205, -0.13316624261798615, 1.0718353018023767)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 1.0073034763336182 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32858.43671789125, 32824.72645924492, 51250.77348469084, 0.999999999998181, 1.0000000000038654, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0010105088490362896 - LearningRate: 119.33665439749731
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.03555617085509723, 0.07005542095641312, -0.005728790763610873)
# Offset in voxels (X, Y, Z): (-0.8127872740314821, -0.12211562887465391, 2.19357766887359)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008896264887747704 - LearningRate: 211.24296907366534
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04166236719426017, 0.06922573409775211, -0.005887935573221314)
# Offset in voxels (X, Y, Z): (-0.8148414300585983, -0.14416636059957175, 2.2166706723581555)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008871640411059488 - LearningRate: 418.3948223638278
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04564240666907108, 0.06763626447894099, -0.00647658132908534)
# Offset in voxels (X, Y, Z): (-0.8177408575568375, -0.11232040550673152, 2.2745844150616032)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008796825515855272 - LearningRate: 89.21388613455292
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04932347981783236, 0.06731345004507272, -0.006482366290374721)
# Offset in voxels (X, Y, Z): (-0.8185513059372155, -0.13382292978214128, 2.278565428707271)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0008771808842659538 - LearningRate: 322.60763199156804
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05619219450154746, 0.06618863393750578, -0.006738375872245112)
# Offset in voxels (X, Y, Z): (-0.8209499186236063, -0.15024095953600156, 2.3056793240760167)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0008756215669311694 - LearningRate: 317.86258153546464
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.058228373944012854, 0.06512729742800068, -0.007139601626096393)
# Offset in voxels (X, Y, Z): (-0.8225538018307879, -0.12325469915996826, 2.338023649442305)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0008710715332999363 - LearningRate: 70.36192227025316
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06046048991257229, 0.06490115953867498, -0.0071555438686079975)
# Offset in voxels (X, Y, Z): (-0.8230708581098104, -0.13490165120101677, 2.3403659994310426)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0008703023044188679 - LearningRate: 92.74456280647813
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06238162678695471, 0.06460895355737971, -0.007213602105817055)
# Offset in voxels (X, Y, Z): (-0.8236561174416822, -0.1405494647494895, 2.3454622617824064)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0008701043646272507 - LearningRate: 459.7744481073993
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06940707991697401, 0.0631795955599464, -0.007586029603222584)
# Offset in voxels (X, Y, Z): (-0.8262347234182774, -0.14529810936904472, 2.3747474462089557)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0008681035290506152 - LearningRate: 750.5246864686826
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07691526154567506, 0.060964454246099954, -0.008267572878860055)
# Offset in voxels (X, Y, Z): (-0.8294111196276759, -0.12124716660363946, 2.419829937392599)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 18.375757455825806 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33730.382778803316, 33699.71916760383, 51254.884441104194, 0.999999999998181, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0008643592350646617 - LearningRate: 40.81770088460857
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0779423115702679, 0.06067746548114315, -0.008272281835621311)
# Offset in voxels (X, Y, Z): (-0.8279643854452022, -0.12622092610623453, 2.4201649638001306)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008641799956820933 - LearningRate: 11.886235259893208
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07817910726407577, 0.06061388293644996, -0.008276207056762921)
# Offset in voxels (X, Y, Z): (-0.8277161740223837, -0.1271071182899903, 2.4203763394314173)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 4.563134431838989 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139268.95832707596, 139139.84049553447, 206294.34701337427, 0.999999999998181, 0.999999999998181, 1.0000000000095497)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0015247151062474074 - LearningRate: 199.7747961808219
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06654459033851076, 0.05988487209127502, -0.008755756087046507)
# Offset in voxels (X, Y, Z): (-1.6434962983773491, -0.01727875827951378, 4.904872005032673)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0013372753328905506 - LearningRate: 198.4607159632137
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06873903519609853, 0.05971720546679143, -0.008804513100090549)
# Offset in voxels (X, Y, Z): (-1.6436132136178072, -0.028767446862536794, 4.911652811111922)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.001336709303493339 - LearningRate: 983.8546152121423
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07579684719967959, 0.059096563811856566, -0.009162432845933651)
# Offset in voxels (X, Y, Z): (-1.6469984863142053, -0.019073832204376206, 4.957862807570569)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0013321607121506065 - LearningRate: 1555.6902193585167
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08746505604989636, 0.05802443797938222, -0.009640194275110611)
# Offset in voxels (X, Y, Z): (-1.6483071958445836, -0.02723357063379342, 5.00820222744512)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0013298633771678817 - LearningRate: 341.38094911415317
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08770073214118891, 0.05810718687988226, -0.009804611864957772)
# Offset in voxels (X, Y, Z): (-1.6531653117112386, 0.008330886481911104, 5.022778491433088)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0013262083298175903 - LearningRate: 88.7135491380348
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08859912715352915, 0.058008277110110085, -0.009817579728905266)
# Offset in voxels (X, Y, Z): (-1.6523922327577494, 0.002347960651520994, 5.023019993247747)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0013260470500431048 - LearningRate: 78.96363164735476
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08923754120505752, 0.05794424795143274, -0.00983451370195074)
# Offset in voxels (X, Y, Z): (-1.6520991209670552, -0.00012950260101906143, 5.023828021793665)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 86.89105725288391 s
# Initial cost function: 4.66872785758156e-310
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143169.72452005456, 143039.80799564047, 206290.75119845118, 1.0000000000095497, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0023689186070570173 - LearningRate: 125.9342910658712
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08357092385562022, 0.05715867492675462, -0.01015304672240712)
# Offset in voxels (X, Y, Z): (-1.6348172310461133, 0.14219676666674266, 5.05588825147102)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.002232602126199138 - LearningRate: 26.220016229755352
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08445298790488723, 0.05722268251507385, -0.010163720527576251)
# Offset in voxels (X, Y, Z): (-1.6353772791865833, 0.13535536791433156, 5.054255340089842)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 2 - Cost function: 0.002232164094491589 - LearningRate: 7.929960749539358
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08468331430835821, 0.057239629364014236, -0.010167953658836427)
# Offset in voxels (X, Y, Z): (-1.6355014028224055, 0.13392366217040685, 5.053904724990816)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 41.70104932785034 s
# Initial cost function: 0.0

# %%
print(time.time())
# Out:
# 1658182745.913836

# %%
# # Quickly check registration in Fiji (only makes sense if #tiles > 1)
# # Select folder 'run23_G_flameNoKr_y04', and check results with Fiji.
# # Then: Adjust the integer list in diffs: choose good scans only to average.
#
# Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
# path_folder = askdirectory(initialdir=path_save) # show an "Open" dialog box and return the path to the selected file
#
# bin_factor = 4
# ind_slices = np.arange(50, 520-50, 100)
# ind_slices = np.append(ind_slices, 510)
# ind_slices = ind_slices//bin_factor
# # ind_slices = np.linspace(30, 45, 16).astype('int')
# print(ind_slices)
#
# slices = File.File(path_folder+'/00/').read(ind_slices)
# slices_avg = np.copy(slices)
# File.File(path_folder+'/FijiCheck/00/').saveTiffStack(slices, '', ind_slices)
#
# list_dir = [e for e in os.listdir(path_folder) if e != 'FijiCheck']
# for dir in list_dir[1:]:
#     print(dir)
#     slices = File.File(path_folder+'/'+dir+'/b_movingRegisteredToStatic/').read(ind_slices)
#     slices_avg += slices
#     File.File(path_folder+'/FijiCheck/'+dir+'/').saveTiffStack(slices, '', ind_slices)
#
# slices_avg /= len(list_dir)
# File.File(path_folder+'/FijiCheck/avg/').saveTiffStack(slices_avg, '', ind_slices)
#
