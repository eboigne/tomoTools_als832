# %%
# Clear memory
# %reset -f

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import ipywidgets
ipywidgets.Widget.close_all()

import SimpleITK
import datetime
import gc # Garbage collected
import numpy as np
import sys, os
import time
import tifffile
import matplotlib.pyplot as plt
import scipy
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askopenfilenames, askdirectory
import torch
import copy

this_path = os.getcwd()
print(this_path)


import h5py
# import File
from scripts import *
import wrapper_ASTRA
# Out:
# <style>.container { width:90% !important; }</style>
# /global/u2/e/eboigne/tomoTools_als832/tomoTools

# %%
# path_save = '/Documents/nersc_als/2022_wood/'
path_save = '/global/homes/e/eboigne/cfs_als/2022_wood/'

path_in = path_save

# %%
print(torch.version.cuda)
# Out:
# 11.3

# %%
# ===== 21 =======

scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_100425_21_SampleO7_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_100935_21_SampleO7_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_101446_21_SampleO7_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102625_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.0
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102927_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.2
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103229_21_SampleO7_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103532_21_SampleO7_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103832_21_SampleO7_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.53
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104143_21_SampleO7_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104454_21_SampleO7_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.51
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104802_21_SampleO7_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105112_21_SampleO7_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105420_21_SampleO7_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105723_21_SampleO7_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.72
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110021_21_SampleO7_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.93
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110325_21_SampleO7_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110625_21_SampleO7_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110926_21_SampleO7_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.34
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111226_21_SampleO7_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.26
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111544_21_SampleO7_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.8
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111845_21_SampleO7_2xLens_21_cooling_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.15
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112154_21_SampleO7_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.45
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112705_21_SampleO7_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_113214_21_SampleO7_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.85
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174749_24_SampleB2_2xLens_05_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['N_angles_per_half_circle'] = 1313
    scan['COR'] = -17.71
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175049_24_SampleB2_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.715
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175354_24_SampleB2_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175656_24_SampleB2_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.66
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180013_24_SampleB2_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180325_24_SampleB2_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.84
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180627_24_SampleB2_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180929_24_SampleB2_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181233_24_SampleB2_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.8
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181536_24_SampleB2_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181852_24_SampleB2_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182201_24_SampleB2_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.9
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182504_24_SampleB2_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182808_24_SampleB2_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.05
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183113_24_SampleB2_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183424_24_SampleB2_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183729_24_SampleB2_2xLens_21_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184047_24_SampleB2_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.0
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184552_24_SampleB2_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_185100_24_SampleB2_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    path_mask = path_in+'mask_allWhite.tif'

tiles_queue.append(('run24_birch_lowHeat_test2', scans))

# %%
for scan in scans_queue:
    print(scan)

# %%
for scan in scans_queue:
    reconstruct_scan(path_in, scan, path_save = path_save)
# Out:
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5
# 	- 10 dark fields
# 	- 0 white fields
# 	- 385 projections
# 	- Image size: (1396, 2560)
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	- 10 dark fields
# 	- 100 white fields
# 	- 5249 projections
# 	- Image size: (1396, 2560)
# 	Importing dark -- Done
# 	Binning dark data ..... Done
# Processing file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	Importing flat -- Done
# 	Importing projections -- Done
# 	Binning data .............................................. Done
# 	Removing outliers (zingers) for flats  Done
# 	Removing outliers (zingers) for proj .............. Done
# 	Computing transmission -- Done
# 	Computing double normalization -- Done
# 	Writing PMDOF_DN to tif -- Done
# 	Making sinograms -- Done
# 	Doing FBP reconstruction (1/2) --

# %%
for tile in tiles_queue:
    print(tile[0])
    for e in tile[1]:
        print(e)
# Out:
# run24_birch_lowHeat_test2
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625, 'ind': '01', 'FBP_folder': '20220501_172426_24_SampleB2_2xLens_01_pre_2625_bin1x2x2_FBP_COR_-17.6_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625, 'ind': '02', 'FBP_folder': '20220501_172932_24_SampleB2_2xLens_02_pre_2625_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625, 'ind': '03', 'FBP_folder': '20220501_173451_24_SampleB2_2xLens_03_pre_2625_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '04', 'FBP_folder': '20220501_174332_24_SampleB2_2xLens_04_dry_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'N_angles_per_half_circle': 1313, 'COR': -17.71, 'ind': '05', 'FBP_folder': '20220501_174749_24_SampleB2_2xLens_05_1313_bin1x2x2_FBP_COR_-17.71_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175049_24_SampleB2_2xLens_06_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.715, 'N_angles_per_half_circle': 1313, 'ind': '06', 'FBP_folder': '20220501_175049_24_SampleB2_2xLens_06_1313_bin1x2x2_FBP_COR_-17.715_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '07', 'FBP_folder': '20220501_175354_24_SampleB2_2xLens_07_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '08a', 'FBP_folder': '20220501_175656_24_SampleB2_2xLens_08_1313_bin1x2x2_FBP_COR_-17.66'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '09a', 'FBP_folder': '20220501_180013_24_SampleB2_2xLens_09_1313_bin1x2x2_FBP_COR_-17.75'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10a', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11a', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12a', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14a', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15a', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16a', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17a', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18a', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19a', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20a', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21a', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625, 'ind': '22', 'FBP_folder': '20220501_184047_24_SampleB2_2xLens_22_post_2625_bin1x2x2_FBP_COR_-19.0_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '23', 'FBP_folder': '20220501_184552_24_SampleB2_2xLens_23_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '24', 'FBP_folder': '20220501_185100_24_SampleB2_2xLens_24_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}

# %%
new_tiles_queue = []
for tile in tiles_queue:

    name_tile = tile[0]
    new_scan_list = []

    for ind_scan in range(len(tile[1])):
        this_scan = tile[1][ind_scan]
        list_FBPs = sorted([e for e in os.listdir(this_scan['path_proj'][:-3]) if 'FBP' in e])

        this_scan['ind'] = this_scan['path_proj'].split('/')[-1].split('_')[5]

        if len(list_FBPs) > 1:
            this_scan['FBP_folder'] = list_FBPs[0]
            this_scan['ind'] = this_scan['ind']+'a'
            new_scan_list.append(this_scan)

            new_scan = copy.deepcopy(this_scan)
            new_scan['FBP_folder'] = list_FBPs[1]
            new_scan['ind'] = new_scan['ind'][:-1]+'b'
            new_scan_list.append(new_scan)
        else:
            this_scan['FBP_folder'] = list_FBPs[0]
            new_scan_list.append(this_scan)

    new_tile = (name_tile, new_scan_list)
    new_tiles_queue.append(new_tile)
# Out:
# run24_birch_lowHeat_test2
# 01 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625, 'ind': '01', 'FBP_folder': '20220501_172426_24_SampleB2_2xLens_01_pre_2625_bin1x2x2_FBP_COR_-17.6_c_averaged_half_circles'}
# 02 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625, 'ind': '02', 'FBP_folder': '20220501_172932_24_SampleB2_2xLens_02_pre_2625_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# 03 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625, 'ind': '03', 'FBP_folder': '20220501_173451_24_SampleB2_2xLens_03_pre_2625_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# 04 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '04', 'FBP_folder': '20220501_174332_24_SampleB2_2xLens_04_dry_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# 05 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'N_angles_per_half_circle': 1313, 'COR': -17.71, 'ind': '05', 'FBP_folder': '20220501_174749_24_SampleB2_2xLens_05_1313_bin1x2x2_FBP_COR_-17.71_c_averaged_half_circles'}
# 06 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175049_24_SampleB2_2xLens_06_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.715, 'N_angles_per_half_circle': 1313, 'ind': '06', 'FBP_folder': '20220501_175049_24_SampleB2_2xLens_06_1313_bin1x2x2_FBP_COR_-17.715_c_averaged_half_circles'}
# 07 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '07', 'FBP_folder': '20220501_175354_24_SampleB2_2xLens_07_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# 08a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '08a', 'FBP_folder': '20220501_175656_24_SampleB2_2xLens_08_1313_bin1x2x2_FBP_COR_-17.66'}
# 08b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '08b', 'FBP_folder': '20220501_175656_24_SampleB2_2xLens_08_1313_bin1x2x2_FBP_COR_-17.66_b_180-360_flipped'}
# 09a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '09a', 'FBP_folder': '20220501_180013_24_SampleB2_2xLens_09_1313_bin1x2x2_FBP_COR_-17.75'}
# 09b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '09b', 'FBP_folder': '20220501_180013_24_SampleB2_2xLens_09_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 10a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10a', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84'}
# 10b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10b', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84_b_180-360_flipped'}
# 11a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11a', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75'}
# 11b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11b', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 12a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12a', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75'}
# 12b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12b', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 13a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}
# 13b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13b', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8_b_180-360_flipped'}
# 14a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14a', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0'}
# 14b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14b', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0_b_180-360_flipped'}
# 15a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15a', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1'}
# 15b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15b', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1_b_180-360_flipped'}
# 16a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16a', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9'}
# 16b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16b', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9_b_180-360_flipped'}
# 17a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17a', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1'}
# 17b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17b', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1_b_180-360_flipped'}
# 18a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18a', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05'}
# 18b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18b', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05_b_180-360_flipped'}
# 19a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19a', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2'}
# 19b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19b', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2_b_180-360_flipped'}
# 20a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20a', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6'}
# 20b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20b', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 21a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21a', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6'}
# 21b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21b', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 22 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625, 'ind': '22', 'FBP_folder': '20220501_184047_24_SampleB2_2xLens_22_post_2625_bin1x2x2_FBP_COR_-19.0_c_averaged_half_circles'}
# 23 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '23', 'FBP_folder': '20220501_184552_24_SampleB2_2xLens_23_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}
# 24 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '24', 'FBP_folder': '20220501_185100_24_SampleB2_2xLens_24_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}

# %%
print(new_tiles_queue[0][1][6])
new_tiles_queue[0] = (new_tiles_queue[0][0], new_tiles_queue[0][1][6:])
# Out:
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '07', 'FBP_folder': '20220501_175354_24_SampleB2_2xLens_07_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}

# %%
for new_tile in new_tiles_queue:
    print(new_tile[0])
    for e in new_tile[1]:
        print(e['ind'], e)
# Out:
# run24_birch_lowHeat_test2
# 07 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313, 'ind': '07', 'FBP_folder': '20220501_175354_24_SampleB2_2xLens_07_1313_bin1x2x2_FBP_COR_-17.7_c_averaged_half_circles'}
# 08a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '08a', 'FBP_folder': '20220501_175656_24_SampleB2_2xLens_08_1313_bin1x2x2_FBP_COR_-17.66'}
# 08b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '08b', 'FBP_folder': '20220501_175656_24_SampleB2_2xLens_08_1313_bin1x2x2_FBP_COR_-17.66_b_180-360_flipped'}
# 09a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '09a', 'FBP_folder': '20220501_180013_24_SampleB2_2xLens_09_1313_bin1x2x2_FBP_COR_-17.75'}
# 09b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '09b', 'FBP_folder': '20220501_180013_24_SampleB2_2xLens_09_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 10a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10a', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84'}
# 10b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '10b', 'FBP_folder': '20220501_180325_24_SampleB2_2xLens_10_1313_bin1x2x2_FBP_COR_-17.84_b_180-360_flipped'}
# 11a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11a', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75'}
# 11b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '11b', 'FBP_folder': '20220501_180627_24_SampleB2_2xLens_11_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 12a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12a', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75'}
# 12b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '12b', 'FBP_folder': '20220501_180929_24_SampleB2_2xLens_12_1313_bin1x2x2_FBP_COR_-17.75_b_180-360_flipped'}
# 13a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}
# 13b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13b', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8_b_180-360_flipped'}
# 14a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14a', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0'}
# 14b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14b', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0_b_180-360_flipped'}
# 15a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15a', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1'}
# 15b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15b', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1_b_180-360_flipped'}
# 16a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16a', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9'}
# 16b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16b', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9_b_180-360_flipped'}
# 17a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17a', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1'}
# 17b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17b', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1_b_180-360_flipped'}
# 18a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18a', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05'}
# 18b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18b', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05_b_180-360_flipped'}
# 19a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19a', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2'}
# 19b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19b', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2_b_180-360_flipped'}
# 20a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20a', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6'}
# 20b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20b', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 21a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21a', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6'}
# 21b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21b', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 22 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625, 'ind': '22', 'FBP_folder': '20220501_184047_24_SampleB2_2xLens_22_post_2625_bin1x2x2_FBP_COR_-19.0_c_averaged_half_circles'}
# 23 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '23', 'FBP_folder': '20220501_184552_24_SampleB2_2xLens_23_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}
# 24 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '24', 'FBP_folder': '20220501_185100_24_SampleB2_2xLens_24_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}

# %%
# Test options
# nb_it = 1
# smoothingSigmas = [1]
# shrinkFactors = [8]
# ind_z_start = 20

# # Real
nb_it = 10
smoothingSigmas = [4, 2, 2, 2, 2, 1, 1]
shrinkFactors =   [8, 8, 4, 4, 2, 2, 1]
ind_z_start = 20

path_tile = path_save
for tile in new_tiles_queue:

    name_tile = tile[0]
    print('\n\n============================== NEW TILE ==============================\n')
    print('Processing tile: '+name_tile)

    print('\n\n============ NEW SCAN ============\n')
    print('Processing scan: '+tile[1][0]['path_proj'].split('/')[-1])
    ind = 0

    # static = import_data(path_tile, tile[1][0])
    # File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').saveTiffStack(static)

    static = File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').readAll()

    print(static.shape)
    moving_reg = static

    for ind_scan in range(1, len(tile[1])):
        scan = tile[1][ind_scan]

        print('\n\n============ NEW SCAN ============\n')
        print('Processing scan: '+scan['path_proj'].split('/')[-1])

        static = moving_reg
        moving = import_data(path_tile, scan)

        folder_out_name = path_tile+name_tile+'/'+scan['ind']+'/'
        moving_reg = run_registration(folder_out_name, static, moving, path_mask, save_str='b', nb_it = nb_it, smoothingSigmas = smoothingSigmas, shrinkFactors = shrinkFactors, ind_z_start=ind_z_start)
        print(folder_out_name)

    print('\n')
    print('\n\n')
# Out:
# ============================== NEW TILE ==============================
#
# Processing tile: run24_birch_lowHeat_test2
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_175354_24_SampleB2_2xLens_07_1313.h5
# (698, 1280, 1280)
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_175656_24_SampleB2_2xLens_08_1313.h5
# Importing data:
# This took 29.18336272239685 s
# Initial cost function: 6.92113491557914e-310
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.00042275343724222035 - LearningRate: 316.55474255479197
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.047973812363685434, 0.0029060519989622647, -0.0015256825421028012)
# Offset in voxels (X, Y, Z): (0.004855960206961877, 0.21422244430925835, 0.12879006505790627)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0003066961448972421 - LearningRate: 1292.1888910173816
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.018363275300162723, 0.017694870196329093, 0.0008776519331203176)
# Offset in voxels (X, Y, Z): (-0.0037263081095413935, 0.04921852816779443, 0.3926184862245168)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0002686409633898378 - LearningRate: 329.3036478583718
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04008153390807644, 0.020076385544003515, 0.0004599825313910141)
# Offset in voxels (X, Y, Z): (0.0010991317459015416, 0.1375233584460508, 0.45679591521384577)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.0002468537489519497 - LearningRate: 1333.5206540051608
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03047848217449131, 0.03322507289677267, 0.0025035773568543632)
# Offset in voxels (X, Y, Z): (-0.0021722897559890353, 0.04556382175519495, 0.5984508233186074)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00023812210521784088 - LearningRate: 334.4155319791082
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04393567869033016, 0.03547192383078465, 0.002455423883249835)
# Offset in voxels (X, Y, Z): (0.0021671137704459423, 0.09313609319479621, 0.6328285580099314)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00023191924926958886 - LearningRate: 1141.4612692221172
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04385168202674229, 0.04569172681723442, 0.0040439338408863)
# Offset in voxels (X, Y, Z): (0.0019571650530625004, 0.043814394425678915, 0.6941478752578618)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00022909148645567124 - LearningRate: 348.767574450971
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.052610924676283664, 0.048053648305758895, 0.004206954375181139)
# Offset in voxels (X, Y, Z): (0.005401736634978557, 0.0682783305258785, 0.7138658201601016)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00022728847079583553 - LearningRate: 1135.3900935356492
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.056611717075517036, 0.057505751207390814, 0.005666432350256947)
# Offset in voxels (X, Y, Z): (0.00661431004593587, 0.0353131814478746, 0.7476721944818783)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00022618159646856103 - LearningRate: 352.61789707214666
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06354683800582582, 0.05985060751129671, 0.005904173072013506)
# Offset in voxels (X, Y, Z): (0.009627563957078408, 0.05092489342601422, 0.7595797328966023)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002254194472565383 - LearningRate: 1275.1067092932412
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07055783851859257, 0.06987270356628043, 0.007442551459428727)
# Offset in voxels (X, Y, Z): (0.011944320929870696, 0.024627090065428188, 0.7806899191923993)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.9458067417144775 s
# Initial cost function: -6.826189270278448e+301
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7968.293576031132, 7960.433662721105, 12656.144512995734, 1.0000000000038654, 1.0000000000010232, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0003545052011242953 - LearningRate: 85.50959716249085
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06981143134226155, 0.07175229032483993, 0.007858753315256189)
# Offset in voxels (X, Y, Z): (0.008691573963837903, 0.00282101516330667, 0.7764332720621131)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0003507446782541563 - LearningRate: 121.71027502403899
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07620228814710862, 0.07307777507136773, 0.008165452276485739)
# Offset in voxels (X, Y, Z): (0.010705694285804108, 0.006549435360138937, 0.7789047489810084)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00035032963185096367 - LearningRate: 295.3248497622403
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08556741833705056, 0.07729785045589053, 0.009127742532331755)
# Offset in voxels (X, Y, Z): (0.010389471854091866, -0.012181850411575058, 0.7780508059308453)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00034892733525840195 - LearningRate: 66.29014650933163
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0900624574462569, 0.07780218824621406, 0.009245095083143143)
# Offset in voxels (X, Y, Z): (0.01241394709668539, -0.004912257197731019, 0.7806695652412177)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0003481959588462716 - LearningRate: 328.62859669610407
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.10333329216099517, 0.0818023335043019, 0.01016082950919472)
# Offset in voxels (X, Y, Z): (0.014852444258769647, -0.010258343020994008, 0.7834470500309333)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00034667041198019945 - LearningRate: 668.185931793739
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.12549983716389707, 0.09046782697684773, 0.012120441622377735)
# Offset in voxels (X, Y, Z): (0.015971328328232063, -0.03936881178838085, 0.7844223965805178)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00034454002943606687 - LearningRate: 62.72173972914902
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1303092838312444, 0.09070549733100489, 0.012185204493493399)
# Offset in voxels (X, Y, Z): (0.018700347846396955, -0.02869952268513229, 0.78770880301782)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 7 - Cost function: 0.0003431707867705618 - LearningRate: 310.93847871684756
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14254557802010798, 0.09400372333551063, 0.012939881131406159)
# Offset in voxels (X, Y, Z): (0.021642005069863086, -0.029259288934893508, 0.7911264459202042)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 8 - Cost function: 0.0003422991926444465 - LearningRate: 157.21613383240424
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.145794199269558, 0.09615768935953195, 0.01341593196278137)
# Offset in voxels (X, Y, Z): (0.02047950430221781, -0.0423410157370551, 0.7896484529442969)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0003413318163712523 - LearningRate: 71.51998381137747
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14946392662607197, 0.09670375026099107, 0.013545409446087897)
# Offset in voxels (X, Y, Z): (0.02203803297652883, -0.03795063036679703, 0.791459724300925)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 4.65531063079834 s
# Initial cost function: 1.6e-322
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32870.68646170515, 32824.72645924516, 51224.66795723974, 1.0000000000095497, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0006291732431961702 - LearningRate: 126.24747913579697
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14464323475903557, 0.09674402845065161, 0.014096592033040289)
# Offset in voxels (X, Y, Z): (0.04951019637676342, -0.15487703957050947, 1.572852470251844)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0005986742087033619 - LearningRate: 190.44396396460746
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1505137667386712, 0.09782174126989814, 0.014442476271917666)
# Offset in voxels (X, Y, Z): (0.04935290668796894, -0.147711734704997, 1.586217594674163)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0005975278413105457 - LearningRate: 551.2886169674325
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.16013817085679644, 0.10041223608591854, 0.015710113787771162)
# Offset in voxels (X, Y, Z): (0.05302385329183041, -0.1961024819299893, 1.6067597256817825)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0005926942222092554 - LearningRate: 97.50515491540929
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.16441150332281124, 0.10103415427569794, 0.015837115086384787)
# Offset in voxels (X, Y, Z): (0.05228331399685896, -0.1792488734574646, 1.6151805853654593)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0005904921862791352 - LearningRate: 483.3747384458792
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1764984175218762, 0.1035116850768764, 0.01679780865364185)
# Offset in voxels (X, Y, Z): (0.05336576555742571, -0.18214497668097465, 1.6363317144138871)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0005878902129886269 - LearningRate: 277.6996772256099
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.18001367404311747, 0.10466175491182052, 0.017467097105947006)
# Offset in voxels (X, Y, Z): (0.055961244601770224, -0.21462678274421498, 1.6394336917700643)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0005846580520399187 - LearningRate: 99.46294104742057
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.18348142060455486, 0.10522698975757541, 0.01762329079096571)
# Offset in voxels (X, Y, Z): (0.05559132762116162, -0.20467426986090512, 1.6451891425406904)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0005837525636286691 - LearningRate: 493.08032129752354
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.19470121532450485, 0.10760473508291685, 0.018613605587870216)
# Offset in voxels (X, Y, Z): (0.05708023141576668, -0.21178220605385775, 1.660222985807871)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0005810031882419736 - LearningRate: 479.34111059568056
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.20218045357163103, 0.10960563554684337, 0.019683994896838707)
# Offset in voxels (X, Y, Z): (0.060572891769963444, -0.24788843548228195, 1.6657629606111841)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0005779163030765133 - LearningRate: 92.00603091190163
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.20555389665107276, 0.11013182078763335, 0.019813984417914966)
# Offset in voxels (X, Y, Z): (0.05997579722927314, -0.23557816201467574, 1.67089921946975)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 18.931599617004395 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33755.14151779941, 33699.719167602525, 51247.600246596914, 0.999999999998181, 1.0000000000038654, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0005796083540058713 - LearningRate: 184.52189174095247
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.20686853021536208, 0.10938353247930462, 0.020287992036787463)
# Offset in voxels (X, Y, Z): (0.07440002070683042, -0.2606171518916208, 1.6702638289967686)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0005763031027853822 - LearningRate: 106.9353887614736
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.20976446492888298, 0.11040482609103215, 0.020466428909964616)
# Offset in voxels (X, Y, Z): (0.06983823253628106, -0.25549153453848766, 1.6739162258743898)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0005758193094385281 - LearningRate: 530.1244392466153
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.21987632378100277, 0.11279453978785339, 0.02153113460112393)
# Offset in voxels (X, Y, Z): (0.07072802444276255, -0.26786091856512595, 1.6836423565577054)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0005731355756416366 - LearningRate: 2628.053484832775
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.26534376357790573, 0.12082802313501105, 0.026908872937652525)
# Offset in voxels (X, Y, Z): (0.10580961334809917, -0.3531191415100758, 1.7188281974637059)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0005651430202447114 - LearningRate: 97.7134188087222
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.2688700680398028, 0.12341779716706486, 0.026990881508445485)
# Offset in voxels (X, Y, Z): (0.08611873758500123, -0.3362919210915978, 1.7228720355681386)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0005610580422601189 - LearningRate: 206.99615857587307
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.27246559357521843, 0.12477102289274361, 0.027355172338138504)
# Offset in voxels (X, Y, Z): (0.08112331118655033, -0.33557863019012807, 1.7245046212506854)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0005607603854462317 - LearningRate: 568.1144357630781
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.2796944660062528, 0.12520610901948814, 0.02848224529125678)
# Offset in voxels (X, Y, Z): (0.09634823324413987, -0.35622570183024393, 1.7246330294732848)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0005591670641650824 - LearningRate: 90.15242816209789
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.2817450751824174, 0.12644044166891405, 0.02860898364025867)
# Offset in voxels (X, Y, Z): (0.08826654421323858, -0.35071765045640857, 1.7263537808922313)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0005585205572254269 - LearningRate: 355.58568584804095
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.28729723255705514, 0.12833509932334494, 0.02923565694725574)
# Offset in voxels (X, Y, Z): (0.08279700051673992, -0.3516675633884687, 1.7287048723610172)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0005581227692541607 - LearningRate: 289.12043272022686
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.29025141359134143, 0.1279277285512192, 0.029817904189107063)
# Offset in voxels (X, Y, Z): (0.09547916560604147, -0.36549857448569406, 1.7280947184230044)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 24.93102192878723 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139412.52310597087, 139139.84049552373, 206426.13432090808, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0016463606720972571 - LearningRate: 200.44554848791944
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.2841124590700637, 0.1281194494125129, 0.0306822596736135)
# Offset in voxels (X, Y, Z): (0.18598698613716513, -0.8894409715386393, 3.429889506286266)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.00156775959740991 - LearningRate: 388.95118547726975
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.28939821691412304, 0.12807115571661767, 0.0321210244385886)
# Offset in voxels (X, Y, Z): (0.18428407065178726, -0.8784960310016386, 3.451737005486616)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0015657321693542 - LearningRate: 583.7455811746752
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.29312026313204526, 0.1278437672942228, 0.03434489673979349)
# Offset in voxels (X, Y, Z): (0.18450343393481297, -0.9365141498334969, 3.4650346741731846)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0015601987017551454 - LearningRate: 176.54754481057103
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.2962266847288014, 0.12785957778970805, 0.03498758412712641)
# Offset in voxels (X, Y, Z): (0.18314160662528947, -0.9160483749162045, 3.4768157713294436)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0015578917091917518 - LearningRate: 875.2216574611621
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3049384931863903, 0.1276514322344208, 0.038274190908404074)
# Offset in voxels (X, Y, Z): (0.1813898600213657, -0.935892292575483, 3.506087179471815)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0015517820018728363 - LearningRate: 1854.0700264670054
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.31930682595865656, 0.1271527182307811, 0.04528472528412342)
# Offset in voxels (X, Y, Z): (0.1789099728481135, -1.031120803804882, 3.5432370631792653)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0015434057969052853 - LearningRate: 162.52305554095966
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3225730642556857, 0.12714798683424455, 0.04586478793820269)
# Offset in voxels (X, Y, Z): (0.1780360425458891, -0.9984736722955023, 3.554125724047765)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0015388674850018152 - LearningRate: 805.6962683838703
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3301468390333059, 0.12693627737026836, 0.048864386329927526)
# Offset in voxels (X, Y, Z): (0.17687309591868972, -0.994160964651783, 3.571282123356089)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0015370855088395216 - LearningRate: 353.4217322809973
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.331071312998549, 0.12682442050735354, 0.05020611306032463)
# Offset in voxels (X, Y, Z): (0.17658675046070144, -1.0332010476213607, 3.56841451420216)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 9 - Cost function: 0.001533577982742062 - LearningRate: 177.5988437651414
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.33316615812518474, 0.1267836254149917, 0.050854240761587614)
# Offset in voxels (X, Y, Z): (0.17617822801947253, -1.0220339470946966, 3.5739253778162015)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 133.1247992515564 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143324.23582877216, 143039.8079956375, 206542.9858937121, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.005411776658255814 - LearningRate: 106.59445259427753
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3284847104512255, 0.12584820963482388, 0.05208442198096393)
# Offset in voxels (X, Y, Z): (0.18224829771842666, -1.153025283927637, 3.549764131658055)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.005274014700179509 - LearningRate: 82.9987527533745
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.33079348890539295, 0.12546961171130191, 0.053176343627298034)
# Offset in voxels (X, Y, Z): (0.17938223807057538, -1.142373414793909, 3.5562907620319115)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 2 - Cost function: 0.00527198359618228 - LearningRate: 411.46030113282023
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.33857743533612283, 0.12326983343839963, 0.05849075814602351)
# Offset in voxels (X, Y, Z): (0.17208097287069923, -1.1560491107031723, 3.5728772151137953)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 3 - Cost function: 0.005257683875221981 - LearningRate: 693.3098983537391
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.34783502449877884, 0.11945460325160644, 0.06720178923478996)
# Offset in voxels (X, Y, Z): (0.1651677052847583, -1.2315829449591436, 3.58288167153825)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 4 - Cost function: 0.005237711056680664 - LearningRate: 73.1244352579883
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3504893494214297, 0.11922231286023313, 0.06812689951517191)
# Offset in voxels (X, Y, Z): (0.1614311507161247, -1.2046846812642757, 3.5910067021443384)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 5 - Cost function: 0.005229945534699776 - LearningRate: 175.05517065345163
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3538039774770179, 0.11841584077315591, 0.07026477665581297)
# Offset in voxels (X, Y, Z): (0.15776050610936845, -1.196795860109675, 3.5975405993706344)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 6 - Cost function: 0.005228069544011192 - LearningRate: 448.8808850946584
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3582975136593556, 0.11609196203777576, 0.07560044829941659)
# Offset in voxels (X, Y, Z): (0.15446537471896152, -1.2476403148562585, 3.5974328034516567)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 7 - Cost function: 0.005216872093028639 - LearningRate: 72.09317501761659
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3603529151940808, 0.11584506535099931, 0.07646415031629192)
# Offset in voxels (X, Y, Z): (0.15160455824266386, -1.2289983225357437, 3.603203357626615)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0052129313926829 - LearningRate: 242.2820716948617
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.36426979865479314, 0.1147742903771075, 0.0792865823842602)
# Offset in voxels (X, Y, Z): (0.14713141412635228, -1.2217930270668471, 3.6099260199849468)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 9 - Cost function: 0.00521086647239921 - LearningRate: 288.9849337217862
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.36621888359282906, 0.1133273317919158, 0.08253833475784379)
# Offset in voxels (X, Y, Z): (0.1459923674751422, -1.2611243659691904, 3.606624297989231)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 150.17883467674255 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (590913.3225909269, 589844.0846080525, 829274.8534159807, 1.0000000000209184, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.02158942505746448 - LearningRate: 152.65542690299304
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3637005872606772, 0.11286202699152759, 0.08367440912089014)
# Offset in voxels (X, Y, Z): (0.2609177316450085, -2.698455444082979, 7.190800035049903)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.021430135047155352 - LearningRate: 199.31987254054224
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.36634530904380036, 0.1112409584581282, 0.08631689260532018)
# Offset in voxels (X, Y, Z): (0.24516810074427883, -2.668238374701528, 7.217416190965245)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 2 - Cost function: 0.021417808864540953 - LearningRate: 714.2811154401531
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.37005647002397307, 0.10518262540805093, 0.09447656185073504)
# Offset in voxels (X, Y, Z): (0.22393501096034224, -2.807688648399242, 7.250042678619191)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 3 - Cost function: 0.021367888192176752 - LearningRate: 106.26868174087136
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.37236797757266454, 0.10460025565584978, 0.0958688594256286)
# Offset in voxels (X, Y, Z): (0.209093865775319, -2.7485323617265554, 7.267079910653485)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 4 - Cost function: 0.021342073756834577 - LearningRate: 526.8192875140405
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.37756240366383303, 0.10101473618854037, 0.10156817139763714)
# Offset in voxels (X, Y, Z): (0.18169571885988317, -2.7275128571373197, 7.292786590558944)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 5 - Cost function: 0.021325980567417923 - LearningRate: 264.73328544855826
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.37772451174166494, 0.09916585340565073, 0.10377259015449888)
# Offset in voxels (X, Y, Z): (0.18319807239142888, -2.817926310416561, 7.280863162696709)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 6 - Cost function: 0.021289389727286674 - LearningRate: 98.30153321583784
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3791583536835208, 0.09865074347696035, 0.10480553461128932)
# Offset in voxels (X, Y, Z): (0.1746373275003545, -2.7899624618003025, 7.289007373964106)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 7 - Cost function: 0.021282922575229474 - LearningRate: 487.32272614978655
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.3833563625070323, 0.09579398411919754, 0.10933946995594579)
# Offset in voxels (X, Y, Z): (0.15351636523466214, -2.7769173211015485, 7.302429903595462)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 8 - Cost function: 0.021269333355621534 - LearningRate: 337.95612440267485
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.38401668449587467, 0.09376531962018052, 0.1118595249773352)
# Offset in voxels (X, Y, Z): (0.15331852330323223, -2.8590910488621084, 7.290641865890349)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 9 - Cost function: 0.021239600591346386 - LearningRate: 86.12532216524158
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.38523664988775463, 0.09339369350995981, 0.11265892617388795)
# Offset in voxels (X, Y, Z): (0.14594000615722777, -2.832471388551939, 7.29742011000045)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 994.3243591785431 s
# Applying transform to volume, took 4.305337190628052 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.38523664988775463, 0.09339369350995981, 0.11265892617388795)
# Offset in voxels (X, Y, Z): (0.14594000615722777, -2.832471388551939, 7.29742011000045)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 1430.3801527023315 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/08a/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_175656_24_SampleB2_2xLens_08_1313.h5
# Importing data:
# This took 29.69298505783081 s
# Initial cost function: 6.9211870023139e-310
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0004654962118481237 - LearningRate: 347.7890170431103
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04511914103117541, 0.006676592750122655, 0.001522984700422456)
# Offset in voxels (X, Y, Z): (-0.03018663137115131, -0.2145322613545256, 0.058502310198387725)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00037755591785861524 - LearningRate: 936.2280841327561
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.023887935283974492, 0.006422933232175734, 0.00046810173818376824)
# Offset in voxels (X, Y, Z): (-0.02110510432044265, -0.14245601010684603, 0.3060350308551637)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003408125737135982 - LearningRate: 372.2762495004532
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0465918217034341, 0.010181320200898656, 0.0012689471023785948)
# Offset in voxels (X, Y, Z): (-0.037421505675143754, -0.2595514874644611, 0.3473809017847749)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.0003162583755154967 - LearningRate: 756.9327659186263
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.03166173655244704, 0.010069793274316433, 0.0006962388752839982)
# Offset in voxels (X, Y, Z): (-0.03215941183801026, -0.22011533938910988, 0.46952105718748893)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00030365904263686356 - LearningRate: 406.4383543559006
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04212310462163162, 0.012278557304909173, 0.001106973951904991)
# Offset in voxels (X, Y, Z): (-0.04104282641949586, -0.2851272836037431, 0.5028780809291529)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00029694800978522277 - LearningRate: 839.611438901766
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.027804077159512046, 0.012324659140818903, 0.0006690110213178924)
# Offset in voxels (X, Y, Z): (-0.0369942158126057, -0.2568022932723834, 0.5919322265688571)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00029050861148510705 - LearningRate: 375.12531076889576
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.034326356674793015, 0.013920433815133419, 0.000972800204962751)
# Offset in voxels (X, Y, Z): (-0.04330447091674631, -0.30411409396074, 0.6096136194740289)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.000286823001970229 - LearningRate: 922.425749264295
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.021140845609935243, 0.014177638624010223, 0.0006648171153846836)
# Offset in voxels (X, Y, Z): (-0.04062737469172071, -0.2877094616569476, 0.67172450940822)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00028422666003690344 - LearningRate: 350.0177030746472
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.024187298223743294, 0.01524203057674588, 0.0008589420755108188)
# Offset in voxels (X, Y, Z): (-0.04462291624308136, -0.31877306817128975, 0.6810644907902138)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.00028267283459762504 - LearningRate: 1284.1229053908166
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.008952718681842109, 0.015857715599630163, 0.0006125425513814356)
# Offset in voxels (X, Y, Z): (-0.04293087924300459, -0.31253312466381894, 0.7333872240112543)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.3751137256622314 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7962.216262492372, 7960.433662721273, 12643.18207656633, 0.999999999998181, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005048283014987958 - LearningRate: 95.83180331408357
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.003166247334903748, 0.01708149681918556, 0.0004966164749673352)
# Offset in voxels (X, Y, Z): (-0.0466328486282738, -0.29441450510145073, 0.7391294281074908)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0005013022546115494 - LearningRate: 12.628977347389188
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0031707912250454173, 0.017084711011520967, 0.0005134431594329798)
# Offset in voxels (X, Y, Z): (-0.04644256685384192, -0.29556414384517576, 0.7391047025011027)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 1.0201458930969238 s
# Initial cost function: 1.58e-321
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32832.83864223757, 32824.72645924429, 51208.28146857231, 0.999999999998181, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.000984175144962768 - LearningRate: 123.58373533826659
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010516940579135626, 0.017396248678061752, 0.00028848575933961246)
# Offset in voxels (X, Y, Z): (-0.08898641624156191, -0.4710055600091586, 1.515833377632766)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0009002735990527186 - LearningRate: 44.884659768462214
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010324047271105074, 0.017592159508843477, 0.0003868933706063999)
# Offset in voxels (X, Y, Z): (-0.08888758788005789, -0.47686035852290093, 1.5178808855822838)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0009001323330088506 - LearningRate: 29.946339432591525
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0103314378505256, 0.017724218970410283, 0.00044780216765981867)
# Offset in voxels (X, Y, Z): (-0.08882103371141124, -0.47946505778425047, 1.5195053896303194)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 6.017802476882935 s
# Initial cost function: 4.6821519747016e-310
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33708.62993161618, 33699.71916760233, 51202.54636169972, 0.9999999999981823, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.000900098317677484 - LearningRate: 30.86188161718676
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.010351388969335951, 0.017814889112381205, 0.0005101575528127632)
# Offset in voxels (X, Y, Z): (-0.08837539268304409, -0.4818316358278118, 1.5212371321495237)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 2.7273459434509277 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139177.77370347886, 139139.84049552926, 206091.82402209565, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.001796682983379713 - LearningRate: 196.85490574442764
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.023383145183633523, 0.01823171182575929, 0.0012565587615037766)
# Offset in voxels (X, Y, Z): (-0.16750279880830435, -0.7578889448946241, 3.111688572273255)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0016347844829510169 - LearningRate: 321.3411859267717
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.024411617768521857, 0.01946696472465938, 0.0029136605131699516)
# Offset in voxels (X, Y, Z): (-0.16536035191972007, -0.7982113987939792, 3.1366733957864477)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.00163192612995938 - LearningRate: 817.5322203301234
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03363948340325022, 0.022694845392859483, 0.006950029184390988)
# Offset in voxels (X, Y, Z): (-0.16129618193205433, -0.7752230723103244, 3.221966227446085)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0016207897359077526 - LearningRate: 148.7031493609914
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03294375786201098, 0.023206259056481243, 0.007724714348419932)
# Offset in voxels (X, Y, Z): (-0.15989029925160897, -0.8140272476479011, 3.2248744093589767)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0016167310460156667 - LearningRate: 637.7417698502811
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03629519445817306, 0.02553220147594414, 0.010891296367445182)
# Offset in voxels (X, Y, Z): (-0.1556957711965031, -0.8616068456254656, 3.2625190958789023)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0016139806663910113 - LearningRate: 425.4912816198886
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04182914899183401, 0.027098504531491187, 0.012896872749082985)
# Offset in voxels (X, Y, Z): (-0.15360664224530557, -0.829246255028312, 3.297367512221804)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0016068529867478694 - LearningRate: 130.00665571573313
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04178372467172159, 0.027529864494649853, 0.013542636604033187)
# Offset in voxels (X, Y, Z): (-0.15254205163141993, -0.8510925457803854, 3.2999841459128407)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0016056739658463295 - LearningRate: 401.08937149151717
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.043777693931611274, 0.02890024857205112, 0.015479801192701854)
# Offset in voxels (X, Y, Z): (-0.1498637688882945, -0.8782575743032872, 3.316494940377003)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 8 - Cost function: 0.001604671983160744 - LearningRate: 833.5441514115319
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.051779446370102004, 0.031765807962956874, 0.019376815479349798)
# Offset in voxels (X, Y, Z): (-0.14525988276346763, -0.8595493314408843, 3.3636010643238223)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0015986490371581723 - LearningRate: 122.41240497126127
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.051465051061697596, 0.03213412427955346, 0.019970636948790865)
# Offset in voxels (X, Y, Z): (-0.1441925355206682, -0.8834833272487911, 3.3632828715523067)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 118.18429756164551 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143111.8398709061, 143039.8079956406, 206123.6360734042, 1.0000000000209184, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.004202640014408476 - LearningRate: 155.59602727564877
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06063272258662075, 0.03314507173806158, 0.023214627988200946)
# Offset in voxels (X, Y, Z): (-0.1344573855281757, -0.7735256006128974, 3.3988692711708706)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0040688837379998935 - LearningRate: 10.994893901222348
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06050689321972363, 0.03325375147933981, 0.02344178485796725)
# Offset in voxels (X, Y, Z): (-0.13456452450588563, -0.7805249429732903, 3.397989351427861)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 2 - Cost function: 0.004068475193844896 - LearningRate: 1.0913560264580897
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06049846467773003, 0.033264354796362465, 0.023464285759742794)
# Offset in voxels (X, Y, Z): (-0.1345717695864059, -0.7811401522201802, 3.3979195339683788)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 40.30090951919556 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (590157.7406512105, 589844.0846080633, 827148.002160763, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.017959364584068733 - LearningRate: 63.667145340077255
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06317297137618176, 0.03358636498356543, 0.025714048723178826)
# Offset in voxels (X, Y, Z): (-0.25057715310549855, -1.504622433354137, 6.817592590131494)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# ...
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0609086660433558, 0.04582013423639108, 0.0028397835107907532)
# Offset in voxels (X, Y, Z): (-0.05504651097172742, 0.09968840502225054, 0.9408123861633477)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 3.535431385040283 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7965.586357382373, 7960.433662721443, 12652.370820442331, 0.999999999998181, 1.0000000000010232, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.001906827193483024 - LearningRate: 75.07336831330207
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.054432500022538216, 0.048085347190619625, 0.0032083727586815734)
# Offset in voxels (X, Y, Z): (-0.06663448376731734, 0.05636278448652726, 0.9323831748585222)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0018895577204940082 - LearningRate: 92.56263560382956
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.05841361526690053, 0.04775508383151064, 0.0032359386038861826)
# Offset in voxels (X, Y, Z): (-0.06574147059412964, 0.0585418072299104, 0.9356232166391828)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 0.9789466857910156 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32847.40977449921, 32824.72645924442, 51204.64486052517, 1.0000000000095497, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0029027922441548573 - LearningRate: 120.83298565161613
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04778990787730798, 0.047430906517709086, 0.0036945290353887664)
# Offset in voxels (X, Y, Z): (-0.13247102557946283, -0.011281721832232777, 1.853848725019606)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0028212920815594046 - LearningRate: 274.1205549349753
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.054978815506957976, 0.04703726023526229, 0.003598186257965766)
# Offset in voxels (X, Y, Z): (-0.13434239805778173, -0.004478600634727697, 1.8840670149241499)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0028192515469332496 - LearningRate: 352.405219199851
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0582292652596159, 0.0463245163924796, 0.003707485099226518)
# Offset in voxels (X, Y, Z): (-0.13484130984383513, -0.052559507625562316, 1.9059173656898782)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0028142438669531435 - LearningRate: 94.4436630323051
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06207512451444037, 0.04628055501041433, 0.003629912069828119)
# Offset in voxels (X, Y, Z): (-0.13585195638869962, -0.03698582224815722, 1.9173783646994436)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.002812457381315336 - LearningRate: 468.1976143283541
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0728007196381189, 0.04569426286311313, 0.0035578875012477647)
# Offset in voxels (X, Y, Z): (-0.13805519880748934, -0.039048954860888274, 1.9545206527404966)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.002809785139637641 - LearningRate: 312.37408692652787
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07547222535602628, 0.04517763584217767, 0.003686014027106495)
# Offset in voxels (X, Y, Z): (-0.138111579979477, -0.08236552812299036, 1.9654606368005647)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.002804897212612228 - LearningRate: 76.76637492099502
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07844550923721386, 0.045155694540836774, 0.003632954814663811)
# Offset in voxels (X, Y, Z): (-0.13877237008344717, -0.07076312931165535, 1.9727652217016565)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.002803927520866821 - LearningRate: 154.54265750531573
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08239250326453125, 0.04502611209813735, 0.0036020047762417144)
# Offset in voxels (X, Y, Z): (-0.13946881450408338, -0.06674736490993025, 1.982758785382358)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0028034962940443457 - LearningRate: 766.1340235310727
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0954758949065667, 0.04414898559644942, 0.0036919208684290743)
# Offset in voxels (X, Y, Z): (-0.14097273844616504, -0.10771590879960283, 2.0158883113217088)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0027964572079323953 - LearningRate: 60.9282128140911
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.09743992129084295, 0.04413289155361358, 0.003665999102639084)
# Offset in voxels (X, Y, Z): (-0.1413416437318534, -0.10177656784382001, 2.019801426378694)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 18.30540132522583 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33721.91296761194, 33699.71916760327, 51226.374183937696, 1.0000000000095497, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0027971143551176907 - LearningRate: 809.3363206854206
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1115885937915399, 0.040877327245978284, 0.0037880767978995178)
# Offset in voxels (X, Y, Z): (-0.11946246652004244, -0.13049877037411095, 2.0473677572361404)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0027938404664309222 - LearningRate: 122.33085686702447
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.11432228992472819, 0.04326400949793945, 0.003737900933487701)
# Offset in voxels (X, Y, Z): (-0.14162144278931882, -0.128571062904381, 2.0510139540117374)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 2 - Cost function: 0.002791089087577959 - LearningRate: 606.4463565363078
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.12471180657253135, 0.04184396042377435, 0.0038203977879080297)
# Offset in voxels (X, Y, Z): (-0.13309270020465147, -0.14691832311293554, 2.0652311439977913)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0027879853619966833 - LearningRate: 165.57340528871714
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.12792911466303403, 0.043022809008955665, 0.003802191448727316)
# Offset in voxels (X, Y, Z): (-0.14457093905645937, -0.14753097716355285, 2.068906194468888)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0027871921015198875 - LearningRate: 539.0134229470915
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.13651077778164905, 0.040817971449490065, 0.003906889380879839)
# Offset in voxels (X, Y, Z): (-0.12793543581629746, -0.16577492313872572, 2.078025012232773)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0027853767584937097 - LearningRate: 119.31577597092806
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.13901076538235702, 0.042388901150263766, 0.0038737917979660757)
# Offset in voxels (X, Y, Z): (-0.14252688087586507, -0.1637698157065367, 2.08054944342869)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 6 - Cost function: 0.002784170345927329 - LearningRate: 591.4993115230657
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1485690115973174, 0.041656946568862194, 0.003946278346207286)
# Offset in voxels (X, Y, Z): (-0.13883637406652904, -0.17878342616927045, 2.089039244866611)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0027814654991102166 - LearningRate: 289.45426849698924
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.15363508337432913, 0.042546930224925346, 0.003943039058235089)
# Offset in voxels (X, Y, Z): (-0.14796428523186833, -0.1809800879513109, 2.093292347876073)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 8 - Cost function: 0.002780904453573043 - LearningRate: 298.18131126027083
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.15761297485676964, 0.04082775409634345, 0.004022806626800204)
# Offset in voxels (X, Y, Z): (-0.13382002682555447, -0.19363668550174393, 2.095603212126462)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 9 - Cost function: 0.002779549167606341 - LearningRate: 108.2971530091045
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1597347037085918, 0.04175917729882588, 0.004002066256750242)
# Offset in voxels (X, Y, Z): (-0.14250628443158556, -0.19181512249639687, 2.0974424721910716)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 18.586238861083984 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139228.77859198165, 139139.8404955305, 206331.30663195922, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.005807846518045108 - LearningRate: 204.70875256568647
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14810018397922806, 0.041296030232819886, 0.004353137566803385)
# Offset in voxels (X, Y, Z): (-0.2799197311019073, -0.613330518054461, 4.153750888265987)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.005634678353715258 - LearningRate: 200.66914795249147
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14983326439024008, 0.04132997084414208, 0.0042797454536830665)
# Offset in voxels (X, Y, Z): (-0.2813538558435477, -0.6078133035065757, 4.166053931825125)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 26.766136169433594 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143132.46057269446, 143039.80799564128, 206323.36068629514, 0.9999999999981921, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.013065907125288876 - LearningRate: 95.90106606172547
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.14473939113617476, 0.04096013277731914, 0.004404273247906234)
# Offset in voxels (X, Y, Z): (-0.2769022009942871, -0.7125489035311694, 4.153396658248643)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.012975280470307665 - LearningRate: 0.07860749427240903
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1447397055257163, 0.04096010553204524, 0.004404234820262472)
# Offset in voxels (X, Y, Z): (-0.27690247984109007, -0.7125594808003924, 4.15340330797428)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 29.661475896835327 s
# Initial cost function: 4.6822836341307e-310
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (590230.3280919478, 589844.0846080596, 827869.2739641657, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.036977475563071106 - LearningRate: 107.9404261671225
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1425443691421965, 0.04054550544752974, 0.004453087904968007)
# Offset in voxels (X, Y, Z): (-0.5418198738217724, -1.5193323313052653, 8.302264122673284)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.03694003881565504 - LearningRate: 0.00934064250324657
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1425443120504534, 0.04054549047239637, 0.0044530879581164)
# Offset in voxels (X, Y, Z): (-0.5418194802102032, -1.5193361988354372, 8.30226466656973)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 248.18036317825317 s
# Applying transform to volume, took 4.287633180618286 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.1425443120504534, 0.04054549047239637, 0.0044530879581164)
# Offset in voxels (X, Y, Z): (-0.5418194802102032, -1.5193361988354372, 8.30226466656973)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 502.5817186832428 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/09a/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_180013_24_SampleB2_2xLens_09_1313.h5
# Importing data:
# This took 27.864466428756714 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0006135473605838234 - LearningRate: 367.8245000984553
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.042187916461323, 0.019406406619639372, 0.0007967674522753386)
# Offset in voxels (X, Y, Z): (-0.10050045893614878, -0.1861596550961771, 0.07123591871728155)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.000528663386233833 - LearningRate: 728.5253897661792
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.029752198523947494, 0.004756291799564044, -0.0007760772466938177)
# Offset in voxels (X, Y, Z): (-0.05096594129919868, -0.1179811890794334, 0.27211565196778786)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)

# %%
print(time.time())
# Out:
# 1658182745.913836

# %%
# # Quickly check registration in Fiji (only makes sense if #tiles > 1)
# # Select folder 'run23_G_flameNoKr_y04', and check results with Fiji.
# # Then: Adjust the integer list in diffs: choose good scans only to average.
#
# Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
# path_folder = askdirectory(initialdir=path_save) # show an "Open" dialog box and return the path to the selected file
#
# bin_factor = 4
# ind_slices = np.arange(50, 520-50, 100)
# ind_slices = np.append(ind_slices, 510)
# ind_slices = ind_slices//bin_factor
# # ind_slices = np.linspace(30, 45, 16).astype('int')
# print(ind_slices)
#
# slices = File.File(path_folder+'/00/').read(ind_slices)
# slices_avg = np.copy(slices)
# File.File(path_folder+'/FijiCheck/00/').saveTiffStack(slices, '', ind_slices)
#
# list_dir = [e for e in os.listdir(path_folder) if e != 'FijiCheck']
# for dir in list_dir[1:]:
#     print(dir)
#     slices = File.File(path_folder+'/'+dir+'/b_movingRegisteredToStatic/').read(ind_slices)
#     slices_avg += slices
#     File.File(path_folder+'/FijiCheck/'+dir+'/').saveTiffStack(slices, '', ind_slices)
#
# slices_avg /= len(list_dir)
# File.File(path_folder+'/FijiCheck/avg/').saveTiffStack(slices_avg, '', ind_slices)
#
