# %%
# Clear memory
# %reset -f

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import ipywidgets
ipywidgets.Widget.close_all()

import SimpleITK
import datetime
import gc # Garbage collected
import numpy as np
import sys, os
import time
import tifffile
import matplotlib.pyplot as plt
import scipy
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askopenfilenames, askdirectory
import torch

this_path = os.getcwd()
print(this_path)
# script_path = this_path+'/../../'
script_path = this_path+'/PhD/Python/'

# script_path = '/home/mihme/Desktop/Github/PhD/Python/'
# script_path = '/home/ihme/eboigne/Python/'
# script_path = '/Documents/Phd/PhD/Python/'

sys.path.append(script_path)
sys.path.append(script_path+'utils/')
sys.path.append(script_path+'io/')
sys.path.append(script_path+'als/')
sys.path.append(script_path+'als/b_commandLineALSscripts_andRelated_before2021/')
sys.path.append(script_path+'als/d_notebookScripts_2021/')

import utils.plot_tools as pt
from rigidTransform3D import *
# from manipulateALSdata import maskSolidWithBorder
from pre_processing_and_reconstruction import *
import h5py
import File
from scripts import *
import wrapper_ASTRA

from k_batch_post_processing_03_run_functions import *

# %%
# path_save = '/home/ihme/eboigne/als2106/'
path_save = '/fastscratch/eboigne/als2106/'
# path_save = '/Documents/Yellowstone/als2106/'

path_in = '/home/ihme/eboigne/als2106/'

print('4')

# %%
# ===== 24 =====

scan = {}
scan['path_proj'] = path_in+'/20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.6
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_174749_24_SampleB2_2xLens_05_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.71
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175049_24_SampleB2_2xLens_06_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.715
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175354_24_SampleB2_2xLens_07_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175656_24_SampleB2_2xLens_08_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.66
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180013_24_SampleB2_2xLens_09_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180325_24_SampleB2_2xLens_10_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.84
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180627_24_SampleB2_2xLens_11_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180929_24_SampleB2_2xLens_12_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181233_24_SampleB2_2xLens_13_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.8
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181536_24_SampleB2_2xLens_14_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.0
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181852_24_SampleB2_2xLens_15_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.1
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182201_24_SampleB2_2xLens_16_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.9
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182504_24_SampleB2_2xLens_17_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182808_24_SampleB2_2xLens_18_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.05
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183113_24_SampleB2_2xLens_19_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.2
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183424_24_SampleB2_2xLens_20_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.6
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183729_24_SampleB2_2xLens_21_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.6
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_184047_24_SampleB2_2xLens_22_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.0
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_184552_24_SampleB2_2xLens_23_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_185100_24_SampleB2_2xLens_24_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scans.append(scan)
scans_queue.append(scan)


# ===== 21 =======

scan = {}
scan['path_proj'] = path_in+'/20220501_100425_21_SampleO7_2xLens_01_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -8.8
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_100935_21_SampleO7_2xLens_02_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -8.8
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_101446_21_SampleO7_2xLens_03_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -8.9
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_102625_21_SampleO7_2xLens_04_dry_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.0
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_102927_21_SampleO7_2xLens_04_dry_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.2
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_103229_21_SampleO7_2xLens_06_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.32
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_103532_21_SampleO7_2xLens_07_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.32
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_103832_21_SampleO7_2xLens_08_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.53
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_104143_21_SampleO7_2xLens_09_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.58
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_104454_21_SampleO7_2xLens_10_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.51
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_104802_21_SampleO7_2xLens_11_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.58
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_105112_21_SampleO7_2xLens_12_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.58
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_105420_21_SampleO7_2xLens_13_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.58
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_105723_21_SampleO7_2xLens_14_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.72
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_110021_21_SampleO7_2xLens_15_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -9.93
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_110325_21_SampleO7_2xLens_16_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -10.1
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_110625_21_SampleO7_2xLens_17_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -10.1
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_110926_21_SampleO7_2xLens_18_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -10.34
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_111226_21_SampleO7_2xLens_19_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -10.26
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_111544_21_SampleO7_2xLens_20_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -11.8
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_111845_21_SampleO7_2xLens_21_cooling_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -11.15
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_112154_21_SampleO7_2xLens_22_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -11.45
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_112705_21_SampleO7_2xLens_23_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -11.6
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_113214_21_SampleO7_2xLens_24_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -11.85
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)


if True:
    scans = []
    scans_queue = []
    tiles_queue = []
    diffs_queue = []

    path_mask = path_in+'/MaskInsideTube_run12.tif'

    # ===== y00 =====

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_103355_run12_L2_1x_B_flameNoKr02_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.7857142857142856
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_105921_run12_L2_1x_B_flameNoKr03_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.7857142857142856
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_112310_run12_L2_1x_B_flameNoKr04_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.5
    scans.append(scan)
    # scans_queue.append(scan)

    # tiles_queue.append(('run12_B_flameNoKr_y00', scans[-3], scans[-2], scans[-1], path_mask))

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_115140_run12_L2_1x_C_flameKr01_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.5
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_121455_run12_L2_1x_C_flameKr02_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.7857142857142856
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_124503_run12_L2_1x_C_flameKr03_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 3.071428571428571
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_130808_run12_L2_1x_C_flameKr04_x00y00.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 2.7857142857142856
    scans.append(scan)
    # scans_queue.append(scan)

    # tiles_queue.append(('run12_C_flameKr_y00', scans[-4], scans[-3], scans[-2], scans[-1], path_mask))
    # diffs_queue.append((tiles_queue[-2], tiles_queue[-1], path_mask, '012', '0123')) # Order is: Ref (flameNoKr, noFlow), Kr (flameKr / coldKr), path_mask, cases_to_use_ref, cases_to_use_Kr
    # diffs_queue.append((tiles_queue[-2], tiles_queue[-1], path_mask, '12', '23')) # Order is: Ref (flameNoKr, noFlow), Kr (flameKr / coldKr), path_mask, cases_to_use_ref, cases_to_use_Kr

    # ===== y01 =====

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_103355_run12_L2_1x_B_flameNoKr02_x00y01.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 1.5714285714285712
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/run12/20210618_105921_run12_L2_1x_B_flameNoKr03_x00y01.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20210618_000120_run11_L2_1x_G_dark_2560x560_x00y01.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = 1.5714285714285712
    scans.append(scan)
    # scans_queue.append(scan)
