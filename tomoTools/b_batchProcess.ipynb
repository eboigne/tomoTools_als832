# %%
# Clear memory
# %reset -f

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import ipywidgets
ipywidgets.Widget.close_all()

import SimpleITK
import datetime
import gc # Garbage collected
import numpy as np
import sys, os
import time
import tifffile
import matplotlib.pyplot as plt
import scipy
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askopenfilenames, askdirectory
import torch

this_path = os.getcwd()
print(this_path)


import h5py
# import File
from scripts import *
import wrapper_ASTRA
# Out:
# <style>.container { width:90% !important; }</style>
# /global/u2/e/eboigne/tomoTools_als832/tomoTools

# %%
# path_save = '/Documents/nersc_als/2022_wood/'
path_save = '/global/homes/e/eboigne/cfs_als/2022_wood/'

path_in = path_save

# %%
print(torch.version.cuda)
# Out:
# 11.3

# %%
scans = []
scans_queue = []
tiles_queue = []


scan = {}
scan['path_proj'] = path_in+'/20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.6
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_174749_24_SampleB2_2xLens_05_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['N_angles_per_half_circle'] = 1313
scan['COR'] = -17.71
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175049_24_SampleB2_2xLens_06_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.715
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175354_24_SampleB2_2xLens_07_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.7
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_175656_24_SampleB2_2xLens_08_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.66
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180013_24_SampleB2_2xLens_09_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180325_24_SampleB2_2xLens_10_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.84
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180627_24_SampleB2_2xLens_11_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_180929_24_SampleB2_2xLens_12_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.75
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181233_24_SampleB2_2xLens_13_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.8
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181536_24_SampleB2_2xLens_14_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.0
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_181852_24_SampleB2_2xLens_15_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.1
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182201_24_SampleB2_2xLens_16_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -17.9
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182504_24_SampleB2_2xLens_17_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_182808_24_SampleB2_2xLens_18_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.05
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183113_24_SampleB2_2xLens_19_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.2
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183424_24_SampleB2_2xLens_20_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.6
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_183729_24_SampleB2_2xLens_21_1313.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -18.6
scan['N_angles_per_half_circle'] = 1313
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_184047_24_SampleB2_2xLens_22_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.0
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_184552_24_SampleB2_2xLens_23_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

scan = {}
scan['path_proj'] = path_in+'/20220501_185100_24_SampleB2_2xLens_24_post_2625.h5'
scan['use_dark_from_scan'] = False
scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
scan['use_flat_from_scan'] = True
scan['COR'] = -19.1
scan['N_angles_per_half_circle'] = 2625
scans.append(scan)
scans_queue.append(scan)

path_mask = path_in+'mask_allWhite.tif'
tiles_queue.append(('run24_birch_lowHeat', scans))

# %%
for scan in scans_queue:
    print(scan)
# Out:
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'N_angles_per_half_circle': 1313, 'COR': -17.71}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175049_24_SampleB2_2xLens_06_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.715, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}

# %%
# Debug on perlmutter
# torch.backends.cudnn.enabled = False

for scan in scans_queue:
    reconstruct_scan(path_in, scan, path_save = path_save)


'''
/global/homes/e/eboigne/miniconda3/envs/tomoTools/lib/python3.6/site-packages/torch/cuda/__init__.py:125: UserWarning:
NVIDIA A100-SXM4-40GB with CUDA capability sm_80 is not compatible with the current PyTorch installation.
The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_61 sm_70 sm_75 compute_37.
If you want to use the NVIDIA A100-SXM4-40GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/

  warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))
'''
# Out:
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5
# 	- 10 dark fields
# 	- 0 white fields
# 	- 385 projections
# 	- Image size: (1396, 2560)
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5
# 	- 10 dark fields
# 	- 100 white fields
# 	- 5249 projections
# 	- Image size: (1396, 2560)
# 	Importing dark -- Done
# 	Binning dark data .......... Done
# Processing file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5
# 	Importing flat -- Done
# 	Importing projections -- Done
# 	Binning data ..................................................................................................................... Done
# 	Removing outliers (zingers) for flats .. Done
# 	Removing outliers (zingers) for proj ................................................................................................................ Done
# 	Computing transmission -- Done
# 	Computing double normalization -- Done
# 	Writing PMDOF_DN to tif -- Done
# 	Making sinograms -- Done
# 	Doing FBP reconstruction (1/2) --

# %%
for tile in tiles_queue:
    print(tile[0])
    for e in tile[1]:
        print(e)
# Out:
# run24_birch_lowHeat
# {'path_proj': '/Documents/nersc_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/Documents/nersc_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/Documents/nersc_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/Documents/nersc_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/Documents/nersc_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/Documents/nersc_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}

# %%
# Test options
# nb_it = 5
# smoothingSigmas = [2, 2, 1]
# shrinkFactors = [1, 1, 1]
# ind_z_start = 2

# # Real
nb_it = 10
smoothingSigmas = [4, 2, 2, 2, 2, 1, 1]
shrinkFactors =   [8, 8, 4, 4, 2, 2, 1]
ind_z_start = 20

path_tile = path_save
for tile in tiles_queue:

    name_tile = tile[0]
    print('\n\n============================== NEW TILE ==============================\n')
    print('Processing tile: '+name_tile)

    ind = 0
    static = import_data(path_tile, tile[1][0])
    print(static.shape)
    File(path_tile+name_tile+'/00/b_movingRegisteredToStatic/').saveTiffStack(static)
    moving_reg = static

    for ind_scan in range(1, len(tile[1])):
        scan = tile[1][ind_scan]

        print('\n\n============ NEW SCAN ============\n')
        print('Processing scan: '+scan['path_proj'].split('/')[-1])

        static = moving_reg
        moving = import_data(path_tile, scan)

        folder_out_name = path_tile+name_tile+'/'+str(ind_scan).zfill(2)+'/'
        moving_reg = run_registration(folder_out_name, static, moving, path_mask, save_str='b', nb_it = nb_it, smoothingSigmas = smoothingSigmas, shrinkFactors = shrinkFactors, ind_z_start=ind_z_start)
        print(folder_out_name)

    print('\n')
    print('\n\n')
# Out:
# ============================== NEW TILE ==============================
#
# Processing tile: run24_birch_lowHeat
# Importing data:
# This took 0.2645587921142578 s
# (10, 1280, 1280)
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5
# Importing data:
# This took 0.2263188362121582 s
# Initial cost function: 6.37e-322
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (408963.09195719345, 408963.0919571937, 817913.6840185534, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 2.5, 0.0)
#
# Iteration: 0 - Cost function: 0.012969970462172636 - LearningRate: 220.31556699600876
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0025809917336904117, 0.00020349112878330372, 0.006257181068023021)
# Offset in voxels (X, Y, Z): (0.39282830766389243, 1.2138331049137114, 0.3004883669402905)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 2.5, 0.0)
#
# Iteration: 1 - Cost function: 0.008793739007188283 - LearningRate: 537.3232966966001
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.007287032178640775, 0.0004149760947986214, 0.02007694829477155)
# Offset in voxels (X, Y, Z): (0.40380467849648194, 0.9085327285389545, 0.5609499788458616)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 2.5, 0.0)
#
#
# Computed transform, took 23.999160766601562 s
# Initial cost function: 6.92105994887223e-310
#
# 	Offset iteration number: 2
# 	Level: 0
# 	Scales: (408977.1335469865, 408977.0918405272, 817914.4503079036, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 4.5, 0.0)
#
# Iteration: 0 - Cost function: 0.008230820699288459 - LearningRate: 433.6931847854362
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.011526062566715399, 0.000798344045158415, 0.03033870668036883)
# Offset in voxels (X, Y, Z): (0.3678054600401185, 1.1835808197554667, 0.8512687655835574)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 4.5, 0.0)
#
# Iteration: 1 - Cost function: 0.008198140229826942 - LearningRate: 373.270956026269
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.014947985672354811, 0.001059331440415272, 0.03924376525064129)
# Offset in voxels (X, Y, Z): (0.3908137952329142, 0.8281620484322955, 0.997237909285371)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 4.5, 0.0)
#
#
# Computed transform, took 25.955578804016113 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 4
# 	Level: 0
# 	Scales: (408999.24550251337, 408999.0916571947, 817915.9747103541, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 6.5, 0.0)
#
# Iteration: 0 - Cost function: 0.043142140970208104 - LearningRate: 2165.6716364935546
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08509847068248905, -0.00017768757919375727, 0.21190845036929803)
# Offset in voxels (X, Y, Z): (0.2712569594377634, 0.5907778866841251, 3.128520162521638)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 6.5, 0.0)
#
# Iteration: 1 - Cost function: 0.03858027257792816 - LearningRate: 101.30536282080114
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08777580141263713, 0.0012668501218318514, 0.21281279514504547)
# Offset in voxels (X, Y, Z): (0.2714107067851528, 0.1911302287764709, 3.067971805828908)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 6.5, 0.0)
#
#
# Computed transform, took 25.5764000415802 s
# Applying transform to volume, took 0.4451255798339844 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08777580141263713, 0.0012668501218318514, 0.21281279514504547)
# Offset in voxels (X, Y, Z): (0.2714107067851528, 0.1911302287764709, 3.067971805828908)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 8.5, 0.0)
# 	 This took: 80.71982479095459 s
# /Documents/nersc_als/2022_wood/run24_birch_lowHeat/01/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_174749_24_SampleB2_2xLens_05_1313.h5
# Importing data:
# This took 0.38367581367492676 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (408963.09195719345, 408963.0919571937, 817913.6840185534, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 2.5, 0.0)
#
# Iteration: 0 - Cost function: 0.03754432562407465 - LearningRate: 344.4435623304627
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0019672468258398914, -0.0005113711051066965, 0.011162675644337493)
# Offset in voxels (X, Y, Z): (0.47011163071592704, 1.1334083850849428, 0.500448301785651)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 2.5, 0.0)
#
# Iteration: 1 - Cost function: 0.017779125837390514 - LearningRate: 303.78751712303074
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0033055231067132336, -0.001484564571679253, 0.02090853764677871)
# Offset in voxels (X, Y, Z): (0.3388156677928199, 0.5824510534100934, 0.6631723511454648)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 2.5, 0.0)
#
#
# Computed transform, took 24.26243495941162 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 2
# 	Level: 0
# 	Scales: (408977.24124193785, 408977.0918405272, 817914.1623321597, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 4.5, 0.0)
#
# Iteration: 0 - Cost function: 0.01788624068575537 - LearningRate: 2012.2176904739208
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.012904347974291614, -0.006996584008181377, 0.0865170737157171)
# Offset in voxels (X, Y, Z): (0.48560894225460444, 1.6095733132518024, 2.5007315592896022)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 4.5, 0.0)
#
# Iteration: 1 - Cost function: 0.006635526984724908 - LearningRate: 212.2316190514914
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.013708799759251886, -0.007747773855902006, 0.09229251574209331)
# Offset in voxels (X, Y, Z): (0.33555725565714895, 0.423054919822516, 2.3829706187753366)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 4.5, 0.0)
#
#
# Computed transform, took 24.94131112098694 s
# Initial cost function: 1.63e-322
#
# 	Offset iteration number: 4
# 	Level: 0
# 	Scales: (409000.2233111342, 408999.09165719466, 817916.7399478036, 0.999999999998181, 0.999999999998181, 0.9999999999999574)
# Fixed parameters (image center): (639.5, 639.5, 6.5, 0.0)
#
# Iteration: 0 - Cost function: 0.010323371063755395 - LearningRate: 282.20329240227
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.017883522611090052, -0.014289250130614464, 0.14352518217450833)
# Offset in voxels (X, Y, Z): (0.28940413537166476, 0.014651992817318493, 2.4509042197292064)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 6.5, 0.0)
#
# Iteration: 1 - Cost function: 0.007168056545535402 - LearningRate: 52.20713724817847
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.01841449818908109, -0.014994189423743361, 0.1499463251471441)
# Offset in voxels (X, Y, Z): (0.2895627414286948, 0.30535979495110044, 2.518482422267787)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 6.5, 0.0)
#
#
# Computed transform, took 25.76644778251648 s
# Applying transform to volume, took 0.4823880195617676 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.01841449818908109, -0.014994189423743361, 0.1499463251471441)
# Offset in voxels (X, Y, Z): (0.2895627414286948, 0.30535979495110044, 2.518482422267787)
# Center of rotation (X, Y, Z, A): (639.5, 639.5, 8.5, 0.0)
# 	 This took: 81.44862484931946 s
# /Documents/nersc_als/2022_wood/run24_birch_lowHeat/02/

# %%
print(time.time())
# Out:
# 1658182745.913836

# %%
# # Quickly check registration in Fiji (only makes sense if #tiles > 1)
# # Select folder 'run23_G_flameNoKr_y04', and check results with Fiji.
# # Then: Adjust the integer list in diffs: choose good scans only to average.
#
# Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
# path_folder = askdirectory(initialdir=path_save) # show an "Open" dialog box and return the path to the selected file
#
# bin_factor = 4
# ind_slices = np.arange(50, 520-50, 100)
# ind_slices = np.append(ind_slices, 510)
# ind_slices = ind_slices//bin_factor
# # ind_slices = np.linspace(30, 45, 16).astype('int')
# print(ind_slices)
#
# slices = File.File(path_folder+'/00/').read(ind_slices)
# slices_avg = np.copy(slices)
# File.File(path_folder+'/FijiCheck/00/').saveTiffStack(slices, '', ind_slices)
#
# list_dir = [e for e in os.listdir(path_folder) if e != 'FijiCheck']
# for dir in list_dir[1:]:
#     print(dir)
#     slices = File.File(path_folder+'/'+dir+'/b_movingRegisteredToStatic/').read(ind_slices)
#     slices_avg += slices
#     File.File(path_folder+'/FijiCheck/'+dir+'/').saveTiffStack(slices, '', ind_slices)
#
# slices_avg /= len(list_dir)
# File.File(path_folder+'/FijiCheck/avg/').saveTiffStack(slices_avg, '', ind_slices)
#
