# %%
# Clear memory
# %reset -f

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import ipywidgets
ipywidgets.Widget.close_all()

import SimpleITK
import datetime
import gc # Garbage collected
import numpy as np
import sys, os
import time
import tifffile
import matplotlib.pyplot as plt
import scipy
from tkinter import Tk
from tkinter.filedialog import askopenfilename, askopenfilenames, askdirectory
import torch
import copy

this_path = os.getcwd()
print(this_path)


import h5py
# import File
from scripts import *
import wrapper_ASTRA
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:90% !important; }</style>
# /global/u2/e/eboigne/tomoTools_als832/tomoTools

# %%
# path_save = '/Documents/nersc_als/2022_wood/'
path_save = '/global/homes/e/eboigne/cfs_als/2022_wood/'

path_in = path_save

# %%
print(torch.version.cuda)
print(torch.cuda.current_device())
# Out:
# 11.3
# 0

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_100425_21_SampleO7_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_100935_21_SampleO7_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_101446_21_SampleO7_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -8.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102625_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.0
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_102927_21_SampleO7_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.2
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103229_21_SampleO7_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103532_21_SampleO7_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.32
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_103832_21_SampleO7_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.53
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104143_21_SampleO7_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104454_21_SampleO7_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.51
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_104802_21_SampleO7_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105112_21_SampleO7_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105420_21_SampleO7_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.58
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_105723_21_SampleO7_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.72
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110021_21_SampleO7_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -9.93
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110325_21_SampleO7_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110625_21_SampleO7_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_110926_21_SampleO7_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.34
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111226_21_SampleO7_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -10.26
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111544_21_SampleO7_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.8
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_111845_21_SampleO7_2xLens_21_cooling_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.15
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112154_21_SampleO7_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.45
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_112705_21_SampleO7_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_113214_21_SampleO7_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -11.85
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

path_mask = path_in+'mask_allWhite.tif'
tiles_queue.append(('run21_oak_lowHeat', scans))

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:

    scan = {}
    scan['path_proj'] = path_in+'/20220501_153433_23_SampleW1_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -15.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_153933_23_SampleW1_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -15.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_154455_23_SampleW1_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -15.9
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_155412_23_SampleW1_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -15.9
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_155728_23_SampleW1_2xLens_05_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_160029_23_SampleW1_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_160331_23_SampleW1_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_160637_23_SampleW1_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_160942_23_SampleW1_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_161249_23_SampleW1_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_161550_23_SampleW1_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.8
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_161852_23_SampleW1_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -23.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_162156_23_SampleW1_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.43
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_162500_23_SampleW1_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.43
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_162802_23_SampleW1_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.61
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_163107_23_SampleW1_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.61
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_163413_23_SampleW1_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.79
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_163718_23_SampleW1_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.72
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_164027_23_SampleW1_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -16.72
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_164340_23_SampleW1_2xLens_20_cooling_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.080000000000002
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_164643_23_SampleW1_2xLens_21_cooling_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_164945_23_SampleW1_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_165449_23_SampleW1_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.5
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_165958_23_SampleW1_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.8
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

path_mask = path_in+'mask_allWhite.tif'
tiles_queue.append(('run23_walnut_lowHeat', scans))

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.6
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_174749_24_SampleB2_2xLens_05_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['N_angles_per_half_circle'] = 1313
    scan['COR'] = -17.71
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175049_24_SampleB2_2xLens_06_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.715
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175354_24_SampleB2_2xLens_07_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_175656_24_SampleB2_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.66
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180013_24_SampleB2_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180325_24_SampleB2_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.84
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180627_24_SampleB2_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_180929_24_SampleB2_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181233_24_SampleB2_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.8
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181536_24_SampleB2_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_181852_24_SampleB2_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182201_24_SampleB2_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.9
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182504_24_SampleB2_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_182808_24_SampleB2_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.05
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183113_24_SampleB2_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183424_24_SampleB2_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_183729_24_SampleB2_2xLens_21_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.6
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    # scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184047_24_SampleB2_2xLens_22_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.0
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_184552_24_SampleB2_2xLens_23_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_185100_24_SampleB2_2xLens_24_post_2625.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -19.1
    scan['N_angles_per_half_circle'] = 2625
    scans.append(scan)
    scans_queue.append(scan)

path_mask = path_in+'mask_allWhite.tif'
tiles_queue.append(('run24_birch_lowHeat_test2', scans))

# %%
scans = []
scans_queue = []
tiles_queue = []

if True:
    scan = {}
    scan['path_proj'] = path_in+'/20220501_201222_26_SampleB3_2xLens_01_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.4
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_201533_26_SampleB3_2xLens_02_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.28
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_201833_26_SampleB3_2xLens_03_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.28
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_202138_26_SampleB3_2xLens_04_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.28
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_202441_26_SampleB3_2xLens_05_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.28
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_202752_26_SampleB3_2xLens_06_pre_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.28
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_202752_26_SampleB3_2xLens_07_dry_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.07
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_203908_26_SampleB3_2xLens_08_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.060000000000002
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_204217_26_SampleB3_2xLens_09_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_204527_26_SampleB3_2xLens_10_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.02
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_204835_26_SampleB3_2xLens_11_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.939999999999998
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_205140_26_SampleB3_2xLens_12_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.05
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_205639_26_SampleB3_2xLens_13_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.3
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_205954_26_SampleB3_2xLens_14_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.1
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_210300_26_SampleB3_2xLens_15_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.8
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_210604_26_SampleB3_2xLens_16_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_210932_26_SampleB3_2xLens_17_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.7
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_211242_26_SampleB3_2xLens_18_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.580000000000002
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_211555_26_SampleB3_2xLens_19_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_211853_26_SampleB3_2xLens_20_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.9
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_212225_26_SampleB3_2xLens_21_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_212618_26_SampleB3_2xLens_22_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_213004_26_SampleB3_2xLens_23_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -17.75
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_213328_26_SampleB3_2xLens_24_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -18.2
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_213652_26_SampleB3_2xLens_25_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.0
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_214006_26_SampleB3_2xLens_26_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.7
    scan['N_angles_per_half_circle'] = 1313
    scan['split_half_circles'] = True
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_214316_26_SampleB3_2xLens_27-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.6
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_214623_26_SampleB3_2xLens_28-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.6
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_214926_26_SampleB3_2xLens_29-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -20.7
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_215226_26_SampleB3_2xLens_30-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -21.0
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_215521_26_SampleB3_2xLens_31-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -21.0
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

    scan = {}
    scan['path_proj'] = path_in+'/20220501_215820_26_SampleB3_2xLens_32-post_1313.h5'
    scan['use_dark_from_scan'] = False
    scan['path_dark'] = path_in+'/20220501_094201_21_dark_2560x1396.h5'
    scan['use_flat_from_scan'] = True
    scan['COR'] = -21.1
    scan['N_angles_per_half_circle'] = 1313
    scans.append(scan)
    scans_queue.append(scan)

path_mask = path_in+'mask_allWhite.tif'
tiles_queue.append(('run26_birch_highHeat', scans))

# %%
for scan in scans_queue:
    print(scan)
# Out:
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}

# %%
for scan in scans_queue:
    reconstruct_scan(path_in, scan, path_save = path_save)
# Out:
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5
# 	- 10 dark fields
# 	- 0 white fields
# 	- 385 projections
# 	- Image size: (1396, 2560)
# Using file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	- 10 dark fields
# 	- 100 white fields
# 	- 5249 projections
# 	- Image size: (1396, 2560)
# 	Importing dark -- Done
# 	Binning dark data ..... Done
# Processing file: /global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5
# 	Importing flat -- Done
# 	Importing projections -- Done
# 	Binning data .............................................. Done
# 	Removing outliers (zingers) for flats  Done
# 	Removing outliers (zingers) for proj .............. Done
# 	Computing transmission -- Done
# 	Computing double normalization -- Done
# 	Writing PMDOF_DN to tif -- Done
# 	Making sinograms -- Done
# 	Doing FBP reconstruction (1/2) --

# %%
for tile in tiles_queue:
    print(tile[0])
    for e in tile[1]:
        print(e)
# Out:
# run24_birch_lowHeat_test2
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172426_24_SampleB2_2xLens_01_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.6, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_172932_24_SampleB2_2xLens_02_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_173451_24_SampleB2_2xLens_03_pre_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174332_24_SampleB2_2xLens_04_dry_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_174749_24_SampleB2_2xLens_05_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'N_angles_per_half_circle': 1313, 'COR': -17.71}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175049_24_SampleB2_2xLens_06_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.715, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175354_24_SampleB2_2xLens_07_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.7, 'N_angles_per_half_circle': 1313}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_175656_24_SampleB2_2xLens_08_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.66, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180013_24_SampleB2_2xLens_09_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180325_24_SampleB2_2xLens_10_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.84, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180627_24_SampleB2_2xLens_11_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_180929_24_SampleB2_2xLens_12_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.75, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625}

# %%
new_tiles_queue = []
for tile in tiles_queue:

    name_tile = tile[0]
    new_scan_list = []

    for ind_scan in range(len(tile[1])):
        this_scan = tile[1][ind_scan]
        list_FBPs = sorted([e for e in os.listdir(this_scan['path_proj'][:-3]) if 'FBP' in e])

        this_scan['ind'] = this_scan['path_proj'].split('/')[-1].split('_')[5]

        if len(list_FBPs) > 1:
            this_scan['FBP_folder'] = list_FBPs[0]
            this_scan['ind'] = this_scan['ind']+'a'
            new_scan_list.append(this_scan)

            new_scan = copy.deepcopy(this_scan)
            new_scan['FBP_folder'] = list_FBPs[1]
            new_scan['ind'] = new_scan['ind'][:-1]+'b'
            new_scan_list.append(new_scan)
        else:
            this_scan['FBP_folder'] = list_FBPs[0]
            new_scan_list.append(this_scan)

    new_tile = (name_tile, new_scan_list)
    new_tiles_queue.append(new_tile)

# %%
print(new_tiles_queue[0][1][23])
new_tiles_queue[0] = (new_tiles_queue[0][0], new_tiles_queue[0][1][23:])
# Out:
# {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}

# %%
for new_tile in new_tiles_queue:
    print(new_tile[0])
    for e in new_tile[1]:
        print(e['ind'], e)
# Out:
# run24_birch_lowHeat_test2
# 13a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13a', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8'}
# 13b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181233_24_SampleB2_2xLens_13_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.8, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '13b', 'FBP_folder': '20220501_181233_24_SampleB2_2xLens_13_1313_bin1x2x2_FBP_COR_-17.8_b_180-360_flipped'}
# 14a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14a', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0'}
# 14b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181536_24_SampleB2_2xLens_14_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.0, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '14b', 'FBP_folder': '20220501_181536_24_SampleB2_2xLens_14_1313_bin1x2x2_FBP_COR_-18.0_b_180-360_flipped'}
# 15a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15a', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1'}
# 15b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_181852_24_SampleB2_2xLens_15_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '15b', 'FBP_folder': '20220501_181852_24_SampleB2_2xLens_15_1313_bin1x2x2_FBP_COR_-18.1_b_180-360_flipped'}
# 16a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16a', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9'}
# 16b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182201_24_SampleB2_2xLens_16_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -17.9, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '16b', 'FBP_folder': '20220501_182201_24_SampleB2_2xLens_16_1313_bin1x2x2_FBP_COR_-17.9_b_180-360_flipped'}
# 17a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17a', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1'}
# 17b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182504_24_SampleB2_2xLens_17_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '17b', 'FBP_folder': '20220501_182504_24_SampleB2_2xLens_17_1313_bin1x2x2_FBP_COR_-19.1_b_180-360_flipped'}
# 18a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18a', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05'}
# 18b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_182808_24_SampleB2_2xLens_18_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.05, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '18b', 'FBP_folder': '20220501_182808_24_SampleB2_2xLens_18_1313_bin1x2x2_FBP_COR_-18.05_b_180-360_flipped'}
# 19a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19a', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2'}
# 19b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183113_24_SampleB2_2xLens_19_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.2, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '19b', 'FBP_folder': '20220501_183113_24_SampleB2_2xLens_19_1313_bin1x2x2_FBP_COR_-18.2_b_180-360_flipped'}
# 20a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20a', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6'}
# 20b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183424_24_SampleB2_2xLens_20_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '20b', 'FBP_folder': '20220501_183424_24_SampleB2_2xLens_20_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 21a {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21a', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6'}
# 21b {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_183729_24_SampleB2_2xLens_21_1313.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -18.6, 'N_angles_per_half_circle': 1313, 'split_half_circles': True, 'ind': '21b', 'FBP_folder': '20220501_183729_24_SampleB2_2xLens_21_1313_bin1x2x2_FBP_COR_-18.6_b_180-360_flipped'}
# 22 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184047_24_SampleB2_2xLens_22_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.0, 'N_angles_per_half_circle': 2625, 'ind': '22', 'FBP_folder': '20220501_184047_24_SampleB2_2xLens_22_post_2625_bin1x2x2_FBP_COR_-19.0_c_averaged_half_circles'}
# 23 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_184552_24_SampleB2_2xLens_23_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '23', 'FBP_folder': '20220501_184552_24_SampleB2_2xLens_23_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}
# 24 {'path_proj': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_185100_24_SampleB2_2xLens_24_post_2625.h5', 'use_dark_from_scan': False, 'path_dark': '/global/homes/e/eboigne/cfs_als/2022_wood//20220501_094201_21_dark_2560x1396.h5', 'use_flat_from_scan': True, 'COR': -19.1, 'N_angles_per_half_circle': 2625, 'ind': '24', 'FBP_folder': '20220501_185100_24_SampleB2_2xLens_24_post_2625_bin1x2x2_FBP_COR_-19.1_c_averaged_half_circles'}

# %%
# Test options
# nb_it = 1
# smoothingSigmas = [1]
# shrinkFactors = [8]
# ind_z_start = 20

# # Real
nb_it = 10
smoothingSigmas = [4, 2, 2, 2, 2, 1, 1]
shrinkFactors =   [8, 8, 4, 4, 2, 2, 1]
ind_z_start = 20

path_tile = path_save
for tile in new_tiles_queue:

    name_tile = tile[0]
    print('\n\n============================== NEW TILE ==============================\n')
    print('Processing tile: '+name_tile)

    print('\n\n============ NEW SCAN ============\n')
    print('Processing scan: '+tile[1][0]['path_proj'].split('/')[-1])
    ind = 0

    # static = import_data(path_tile, tile[1][0])
    # File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').saveTiffStack(static)

    static = File(path_tile+name_tile+'/'+tile[1][0]['ind']+'/b_movingRegisteredToStatic/').readAll()

    print(static.shape)
    moving_reg = static

    for ind_scan in range(1, len(tile[1])):
        scan = tile[1][ind_scan]

        print('\n\n============ NEW SCAN ============\n')
        print('Processing scan: '+scan['path_proj'].split('/')[-1])

        static = moving_reg
        moving = import_data(path_tile, scan)

        folder_out_name = path_tile+name_tile+'/'+scan['ind']+'/'
        moving_reg = run_registration(folder_out_name, static, moving, path_mask, save_str='b', nb_it = nb_it, smoothingSigmas = smoothingSigmas, shrinkFactors = shrinkFactors, ind_z_start=ind_z_start)
        print(folder_out_name)

    print('\n')
    print('\n\n')
# Out:
# ============================== NEW TILE ==============================
#
# Processing tile: run24_birch_lowHeat_test2
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_181233_24_SampleB2_2xLens_13_1313.h5
# (698, 1280, 1280)
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_181233_24_SampleB2_2xLens_13_1313.h5
# Importing data:
# This took 129.22959280014038 s
# Initial cost function: 1.1956827498527426e-71
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0007601150810764845 - LearningRate: 295.7162747251141
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0017393191692307033, 0.08329705703869758, -0.0011054256477955997)
# Offset in voxels (X, Y, Z): (-0.38545776806472476, 0.005102182757745268, 0.10148245282831525)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0004379267429834705 - LearningRate: 1465.991998817407
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.034262087665180206, 0.05562693454980695, -0.0016965611302450533)
# Offset in voxels (X, Y, Z): (-0.2677470651989186, -0.08587191846799044, 0.5771616121470279)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0003358099770646747 - LearningRate: 327.32514249402504
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.03575991520454699, 0.08364447392665678, -0.0021834739545746164)
# Offset in voxels (X, Y, Z): (-0.39985940745205595, -0.08756898825882807, 0.6318236346621876)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00029940633188611695 - LearningRate: 1100.0349703267937
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.046695606646733376, 0.06567510035878323, -0.0025612726411535177)
# Offset in voxels (X, Y, Z): (-0.32893754016232724, -0.12341517399015912, 0.8061527958305339)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00028158800290261276 - LearningRate: 336.1099835420398
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.047482688513428545, 0.08054306514707567, -0.0028824289821462183)
# Offset in voxels (X, Y, Z): (-0.4011836969072729, -0.1257544140273872, 0.8388733463524112)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.000270844373291793 - LearningRate: 1065.5660672253111
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.052480028821004054, 0.06886183212994258, -0.003266154980904868)
# Offset in voxels (X, Y, Z): (-0.36033724832412184, -0.1464628188923649, 0.9375900915702966)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.0002649099254677275 - LearningRate: 341.6415978184534
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05270254987215003, 0.0771546796429498, -0.0035055255756882534)
# Offset in voxels (X, Y, Z): (-0.40269062815691337, -0.14854348053429844, 0.9573366302657954)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00026128475720685893 - LearningRate: 1036.035811075561
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05447791300423308, 0.06908004224592909, -0.0038854828141416573)
# Offset in voxels (X, Y, Z): (-0.37872089790464486, -0.16094915316661373, 1.0145788921643526)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.00025923168317345245 - LearningRate: 345.80330242052577
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.054314375479692194, 0.07365530367930188, -0.004080019189583277)
# Offset in voxels (X, Y, Z): (-0.4041498441825461, -0.16253770403131887, 1.0266396901253396)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002579532375048522 - LearningRate: 1001.0158388092095
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05438608723522273, 0.06781102811776735, -0.004449403699255147)
# Offset in voxels (X, Y, Z): (-0.3901629195991948, -0.1700501958944351, 1.0600745393334647)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.695245981216431 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7968.061461275262, 7960.433662721158, 12654.103346022792, 0.999999999998181, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005036093036925184 - LearningRate: 78.05251555232229
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0476050024160817, 0.07129545785795471, -0.005005029123711315)
# Offset in voxels (X, Y, Z): (-0.4093319437378216, -0.13164505657592657, 1.0712577482866987)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00048690309963626545 - LearningRate: 21.944695884240083
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04833404669674911, 0.07095070551305205, -0.005029537097765442)
# Offset in voxels (X, Y, Z): (-0.4087321611929205, -0.13316624261798615, 1.0718353018023767)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 1.085984706878662 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32858.43671789125, 32824.72645924492, 51250.77348469084, 0.999999999998181, 1.0000000000038654, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0010105088490362896 - LearningRate: 119.33665439749731
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.03555617085509723, 0.07005542095641312, -0.005728790763610873)
# Offset in voxels (X, Y, Z): (-0.8127872740314821, -0.12211562887465391, 2.19357766887359)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008896264887747704 - LearningRate: 211.24296907366534
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04166236719426017, 0.06922573409775211, -0.005887935573221314)
# Offset in voxels (X, Y, Z): (-0.8148414300585983, -0.14416636059957175, 2.2166706723581555)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008871640411059488 - LearningRate: 418.3948223638278
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04564240666907108, 0.06763626447894099, -0.00647658132908534)
# Offset in voxels (X, Y, Z): (-0.8177408575568375, -0.11232040550673152, 2.2745844150616032)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008796825515855272 - LearningRate: 89.21388613455292
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04932347981783236, 0.06731345004507272, -0.006482366290374721)
# Offset in voxels (X, Y, Z): (-0.8185513059372155, -0.13382292978214128, 2.278565428707271)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0008771808842659538 - LearningRate: 322.60763199156804
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05619219450154746, 0.06618863393750578, -0.006738375872245112)
# Offset in voxels (X, Y, Z): (-0.8209499186236063, -0.15024095953600156, 2.3056793240760167)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0008756215669311694 - LearningRate: 317.86258153546464
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.058228373944012854, 0.06512729742800068, -0.007139601626096393)
# Offset in voxels (X, Y, Z): (-0.8225538018307879, -0.12325469915996826, 2.338023649442305)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0008710715332999363 - LearningRate: 70.36192227025316
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06046048991257229, 0.06490115953867498, -0.0071555438686079975)
# Offset in voxels (X, Y, Z): (-0.8230708581098104, -0.13490165120101677, 2.3403659994310426)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0008703023044188679 - LearningRate: 92.74456280647813
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06238162678695471, 0.06460895355737971, -0.007213602105817055)
# Offset in voxels (X, Y, Z): (-0.8236561174416822, -0.1405494647494895, 2.3454622617824064)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0008701043646272507 - LearningRate: 459.7744481073993
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06940707991697401, 0.0631795955599464, -0.007586029603222584)
# Offset in voxels (X, Y, Z): (-0.8262347234182774, -0.14529810936904472, 2.3747474462089557)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0008681035290506152 - LearningRate: 750.5246864686826
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07691526154567506, 0.060964454246099954, -0.008267572878860055)
# Offset in voxels (X, Y, Z): (-0.8294111196276759, -0.12124716660363946, 2.419829937392599)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 18.142173528671265 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33730.382778803316, 33699.71916760383, 51254.884441104194, 0.999999999998181, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0008643592350646617 - LearningRate: 40.81770088460857
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0779423115702679, 0.06067746548114315, -0.008272281835621311)
# Offset in voxels (X, Y, Z): (-0.8279643854452022, -0.12622092610623453, 2.4201649638001306)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008641799956820933 - LearningRate: 11.886235259893208
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07817910726407577, 0.06061388293644996, -0.008276207056762921)
# Offset in voxels (X, Y, Z): (-0.8277161740223837, -0.1271071182899903, 2.4203763394314173)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 4.538700342178345 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139268.95832707596, 139139.84049553447, 206294.34701337427, 0.999999999998181, 0.999999999998181, 1.0000000000095497)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0015247151062474074 - LearningRate: 199.7747961808219
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06654459033851076, 0.05988487209127502, -0.008755756087046507)
# Offset in voxels (X, Y, Z): (-1.6434962983773491, -0.01727875827951378, 4.904872005032673)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0013372753328905506 - LearningRate: 198.4607159632137
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06873903519609853, 0.05971720546679143, -0.008804513100090549)
# Offset in voxels (X, Y, Z): (-1.6436132136178072, -0.028767446862536794, 4.911652811111922)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.001336709303493339 - LearningRate: 983.8546152121423
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.07579684719967959, 0.059096563811856566, -0.009162432845933651)
# Offset in voxels (X, Y, Z): (-1.6469984863142053, -0.019073832204376206, 4.957862807570569)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0013321607121506065 - LearningRate: 1555.6902193585167
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08746505604989636, 0.05802443797938222, -0.009640194275110611)
# Offset in voxels (X, Y, Z): (-1.6483071958445836, -0.02723357063379342, 5.00820222744512)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0013298633771678817 - LearningRate: 341.38094911415317
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08770073214118891, 0.05810718687988226, -0.009804611864957772)
# Offset in voxels (X, Y, Z): (-1.6531653117112386, 0.008330886481911104, 5.022778491433088)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0013262083298175903 - LearningRate: 88.7135491380348
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08859912715352915, 0.058008277110110085, -0.009817579728905266)
# Offset in voxels (X, Y, Z): (-1.6523922327577494, 0.002347960651520994, 5.023019993247747)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0013260470500431048 - LearningRate: 78.96363164735476
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08923754120505752, 0.05794424795143274, -0.00983451370195074)
# Offset in voxels (X, Y, Z): (-1.6520991209670552, -0.00012950260101906143, 5.023828021793665)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 83.173020362854 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143169.72452005456, 143039.80799564047, 206290.75119845118, 1.0000000000095497, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0023689186070570173 - LearningRate: 125.9342910658712
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08357092385562022, 0.05715867492675462, -0.01015304672240712)
# Offset in voxels (X, Y, Z): (-1.6348172310461133, 0.14219676666674266, 5.05588825147102)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.002232602126199138 - LearningRate: 26.220016229755352
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08445298790488723, 0.05722268251507385, -0.010163720527576251)
# Offset in voxels (X, Y, Z): (-1.6353772791865833, 0.13535536791433156, 5.054255340089842)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 2 - Cost function: 0.002232164094491589 - LearningRate: 7.929960749539358
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08468331430835821, 0.057239629364014236, -0.010167953658836427)
# Offset in voxels (X, Y, Z): (-1.6355014028224055, 0.13392366217040685, 5.053904724990816)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 41.90049934387207 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (590383.907014736, 589844.084608052, 827643.6950922812, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.007087045411743572 - LearningRate: 204.14764870832124
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08071803973072941, 0.057013676137073366, -0.011220418446052224)
# Offset in voxels (X, Y, Z): (-3.244734441956741, 0.6042214394735668, 10.178874561618924)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.006551431920206581 - LearningRate: 33.81327535348261
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08202670332730969, 0.05707235930033396, -0.01131818348446218)
# Offset in voxels (X, Y, Z): (-3.2429451289981754, 0.5857074959894792, 10.174790624100629)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 2 - Cost function: 0.006548593575095323 - LearningRate: 11.940897568902754
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08243862408320927, 0.057097405075775626, -0.011354655145994054)
# Offset in voxels (X, Y, Z): (-3.2424949012862365, 0.5810116419127738, 10.173727471099548)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 316.0166594982147 s
# Applying transform to volume, took 4.372338771820068 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.08243862408320927, 0.057097405075775626, -0.011354655145994054)
# Offset in voxels (X, Y, Z): (-3.2424949012862365, 0.5810116419127738, 10.173727471099548)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 572.0485682487488 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/13b/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_181536_24_SampleB2_2xLens_14_1313.h5
# Importing data:
# This took 85.66001629829407 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0011899176931751915 - LearningRate: 282.9942613360546
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08379661287339357, 0.09030147000108003, -0.00485110292576782)
# Offset in voxels (X, Y, Z): (-0.4110564689442614, 0.39906275357863197, 0.17857724343673154)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0004357582489108373 - LearningRate: 1402.9235395161872
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04348240119663825, 0.08274358369972346, -0.004647213392804458)
# Offset in voxels (X, Y, Z): (-0.3816764403812049, 0.2611089644294927, 0.6096909030387847)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00032861705717280166 - LearningRate: 428.65601594233317
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.05582883913882356, 0.09530037587884053, -0.005556969369670823)
# Offset in voxels (X, Y, Z): (-0.4412265158181606, 0.3230010876728005, 0.7022207774778588)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.0003082758811125801 - LearningRate: 629.3944151811969
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03771581338582386, 0.0853235586797508, -0.005027485333089372)
# Offset in voxels (X, Y, Z): (-0.400634736433014, 0.24374456628046492, 0.7912044032189018)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.00029456968645810906 - LearningRate: 436.48220339706916
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.046800204086455584, 0.09372875401776282, -0.0056718959245004395)
# Offset in voxels (X, Y, Z): (-0.4419548709551798, 0.2864014398598167, 0.857457205347681)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.0002846920914217069 - LearningRate: 630.0412025179163
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03465183794491146, 0.08630419063663347, -0.005303909683267577)
# Offset in voxels (X, Y, Z): (-0.4135572796418445, 0.22938913739111916, 0.919783598697688)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.0002778157742889544 - LearningRate: 433.76478881466477
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.04161845119746088, 0.09189808084001784, -0.005764206327972196)
# Offset in voxels (X, Y, Z): (-0.44246984965515995, 0.25927664332106115, 0.9662807166689183)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00027297220495792613 - LearningRate: 659.7213864941635
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03356789053547027, 0.08619151961330392, -0.005510441037108635)
# Offset in voxels (X, Y, Z): (-0.4225028914088102, 0.21726802761223846, 1.0123518001661407)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.0002694404381446507 - LearningRate: 413.72731723333334
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.039097661345117024, 0.08985733916793955, -0.005841395966736603)
# Offset in voxels (X, Y, Z): (-0.4427236800093021, 0.23870474650344595, 1.043723357325339)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.0002670395057401 - LearningRate: 740.6725402690421
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0340394718415522, 0.08530167390843842, -0.0056780964843027)
# Offset in voxels (X, Y, Z): (-0.4288899329346349, 0.20738984587275114, 1.0804739355361699)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.320740461349487 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7970.031037673758, 7960.433662721117, 12653.784131362667, 1.0000000000038654, 0.999999999998181, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005231234457720144 - LearningRate: 82.52864863082871
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.02761157159958856, 0.08810266408415275, -0.005502887946610278)
# Offset in voxels (X, Y, Z): (-0.44624553769753494, 0.16935504287621572, 1.079312277611467)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0005085649129915333 - LearningRate: 67.10258470347313
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.029880894754686246, 0.08696817878923337, -0.005600159341098078)
# Offset in voxels (X, Y, Z): (-0.4438892177731199, 0.17358359267329523, 1.0869387839952573)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 2 - Cost function: 0.0005081179638700003 - LearningRate: 332.65620015909303
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.03485934883777412, 0.08426758727193184, -0.005868427796061658)
# Offset in voxels (X, Y, Z): (-0.4461046627711101, 0.16492888659566882, 1.115632574201906)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 3 - Cost function: 0.000505103701489806 - LearningRate: 1649.1190017984359
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.059387851307392214, 0.0725336474233527, -0.00694323693834283)
# Offset in voxels (X, Y, Z): (-0.46081397120288775, 0.11767550592187255, 1.221212519923754)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0004982822244371721 - LearningRate: 24.167753364853876
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06050108103647928, 0.07209160522812562, -0.006969403552758068)
# Offset in voxels (X, Y, Z): (-0.45946779854179187, 0.12040590212427846, 1.2217073632241517)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 5 - Cost function: 0.0004981853329255693 - LearningRate: 3.017062688394046
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.060612391445486184, 0.07204944625223209, -0.0069717880593198256)
# Offset in voxels (X, Y, Z): (-0.4593621395482559, 0.12061782523387378, 1.2217364786275986)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 2.807845115661621 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32858.95919607185, 32824.72645924636, 51204.50675258083, 1.0000000000038876, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0009596450446872807 - LearningRate: 124.85132632008103
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.050605992188360614, 0.07051175699822558, -0.006568408015223322)
# Offset in voxels (X, Y, Z): (-0.9100504587720124, 0.13055041664167444, 2.433786183394637)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008952100792066139 - LearningRate: 122.38758215943858
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0529736299329894, 0.07026984630973908, -0.0066617362260691)
# Offset in voxels (X, Y, Z): (-0.9120752871703475, 0.13958558709801405, 2.4510237167866995)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008941233710602752 - LearningRate: 606.7275680620751
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.057237455762119596, 0.06836101722529604, -0.006806805690982935)
# Offset in voxels (X, Y, Z): (-0.9156712440759306, 0.11160414560146023, 2.5160573574117264)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008858462743305787 - LearningRate: 178.56512800194002
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.05983669736872213, 0.06797335509219116, -0.006881118483596257)
# Offset in voxels (X, Y, Z): (-0.917455912306249, 0.1156186787496018, 2.5334539642895093)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.000885304629529304 - LearningRate: 885.2236799005591
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06516802613699353, 0.06538759005096297, -0.006921805392474654)
# Offset in voxels (X, Y, Z): (-0.9199393754064062, 0.06203227334288793, 2.597223842201015)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0008794115414544299 - LearningRate: 72.0981156562968
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06756860069038742, 0.0653868801603533, -0.006995114835634494)
# Offset in voxels (X, Y, Z): (-0.9215592265812615, 0.07650311852490815, 2.6049155069465573)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0008779157583526832 - LearningRate: 38.12719582666931
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.06826277475406245, 0.06533265523262004, -0.007010565264288319)
# Offset in voxels (X, Y, Z): (-0.921958913938809, 0.0786024812109752, 2.6076157054706903)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 13.654058933258057 s
# Initial cost function: -159.0339918526297
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33732.58139340007, 33699.71916760276, 51201.06814369774, 0.9999999999982032, 1.0000000000095497, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.000878554746825362 - LearningRate: 286.97702728247066
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0711922753925582, 0.06342357782309464, -0.007008599787431669)
# Offset in voxels (X, Y, Z): (-0.9111652916823099, 0.0733516638849134, 2.623296588127536)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008776757384748427 - LearningRate: 189.1332600015109
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0728727730484636, 0.0644262755488752, -0.007041610866181575)
# Offset in voxels (X, Y, Z): (-0.9243499681190103, 0.06768062093809032, 2.631290648112431)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008767794510478633 - LearningRate: 225.59103207173516
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07522835645946646, 0.06284609551623417, -0.0070316796664617025)
# Offset in voxels (X, Y, Z): (-0.9147665271249412, 0.06417015260232765, 2.6417992261952503)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008761375880204597 - LearningRate: 237.99739888677954
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07740834105627914, 0.06364962508787798, -0.007058848886827716)
# Offset in voxels (X, Y, Z): (-0.9268826222540099, 0.05780872051200304, 2.6505626233849284)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0008754054284304798 - LearningRate: 177.11733132762785
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.07929569327333878, 0.062275191611366576, -0.007044462469906308)
# Offset in voxels (X, Y, Z): (-0.9178921525295103, 0.05558163232237978, 2.657726293659775)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0008748742479452237 - LearningRate: 343.6843397527639
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08251520595499386, 0.0628854400601248, -0.00706650044471608)
# Offset in voxels (X, Y, Z): (-0.9299867819597857, 0.047411765242148754, 2.6688019538244068)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0008741676126232037 - LearningRate: 144.51004915442888
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08409205793495858, 0.0615763021734784, -0.007048505303634775)
# Offset in voxels (X, Y, Z): (-0.9207439499579875, 0.04615506433763528, 2.6738841590677453)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0008736484561556649 - LearningRate: 602.1999962846132
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.089811728980225, 0.06191247267469481, -0.007061165148320469)
# Offset in voxels (X, Y, Z): (-0.9345221185818574, 0.03348622005774417, 2.690420190475956)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0008727893882649268 - LearningRate: 121.64000647981902
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.09118526001684972, 0.060541442419261286, -0.007038839017379384)
# Offset in voxels (X, Y, Z): (-0.9240848179008986, 0.03317841641189526, 2.6940262281265017)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 9 - Cost function: 0.0008721528257066643 - LearningRate: 603.0215158136775
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0969489449698049, 0.060181449227068695, -0.007023412959613601)
# Offset in voxels (X, Y, Z): (-0.9305565580598318, 0.02245184848183483, 2.7069976960706077)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 18.085469484329224 s
# Initial cost function: -159.0180280882123
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139268.03664074984, 139139.84049553183, 206158.6589668446, 0.999999999998181, 0.999999999998181, 1.0000000000095497)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0015483397171175209 - LearningRate: 201.6144172305059
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08515546043043995, 0.05886577243103203, -0.0066491225765658996)
# Offset in voxels (X, Y, Z): (-1.8448869744350092, -0.1823877468712066, 5.3757264815592105)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0013832692423753398 - LearningRate: 173.5254528049416
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08630718521522567, 0.058764129276559766, -0.006701640318512915)
# Offset in voxels (X, Y, Z): (-1.847344749552854, -0.17502936336563213, 5.388810235514281)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.001382842256637129 - LearningRate: 860.2398553805663
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08923370022056827, 0.0578275833752584, -0.006860848407925085)
# Offset in voxels (X, Y, Z): (-1.8519297288820986, -0.18867595261347267, 5.440369769523623)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0013796570322300247 - LearningRate: 1787.750938393385
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.09317711599541817, 0.0557040440681345, -0.007066536541411421)
# Offset in voxels (X, Y, Z): (-1.8550622977783435, -0.2555970869038104, 5.518775079860611)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0013749929759363183 - LearningRate: 120.77590526601301
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.09464466875280854, 0.05574453629884065, -0.007115370545360263)
# Offset in voxels (X, Y, Z): (-1.8579134032741884, -0.23836695255036205, 5.526696868962077)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0013737698419443059 - LearningRate: 48.024623382315795
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.09495797760990367, 0.05572260210797284, -0.007125493651944296)
# Offset in voxels (X, Y, Z): (-1.858406800531807, -0.23636930572652948, 5.528714569842108)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 75.20522594451904 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143164.7410075349, 143039.80799564224, 206168.3078219955, 0.999999999998181, 1.0000000000095497, 1.0000000000095497)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.002838889853722015 - LearningRate: 126.68643463131089
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08784599279126344, 0.054937391852346106, -0.007099761942583672)
# Offset in voxels (X, Y, Z): (-1.8525892823403391, -0.38470935312518684, 5.503173914420353)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.002670416494242177 - LearningRate: 4.4494193745635995
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08797312357383863, 0.05493314571323634, -0.007108178471822401)
# Offset in voxels (X, Y, Z): (-1.8527483845875081, -0.383263617295613, 5.503755332590067)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 30.026304483413696 s
# Initial cost function: 1.63e-322
#
# 	Offset iteration number: 60
# 	Level: 0
# 	Scales: (590362.1456284692, 589844.0846080491, 827203.0106461887, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 0 - Cost function: 0.009682956625030801 - LearningRate: 116.74138794034408
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.08637914811960366, 0.054644810475118995, -0.007759528069474476)
# Offset in voxels (X, Y, Z): (-3.7076430324133858, -0.8649159382381119, 11.001759923972559)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
# Iteration: 1 - Cost function: 0.00962147341899847 - LearningRate: 0.010102235175496375
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0863791760822448, 0.05464478905851654, -0.00775958282481285)
# Offset in voxels (X, Y, Z): (-3.707643353948293, -0.8649185576616858, 11.001760672226297)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 231.46165823936462 s
# Applying transform to volume, took 4.262233257293701 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.0863791760822448, 0.05464478905851654, -0.00775958282481285)
# Offset in voxels (X, Y, Z): (-3.707643353948293, -0.8649185576616858, 11.001760672226297)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 447.03025794029236 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/14a/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_181536_24_SampleB2_2xLens_14_1313.h5
# Importing data:
# This took 33.94283080101013 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0008925021392662545 - LearningRate: 292.88606902265565
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.015591361168185235, 0.09739696479174985, -0.0007597830053316625)
# Offset in voxels (X, Y, Z): (-0.45243247000457193, -0.060632816229890696, 0.09152787829412647)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0004491418938007836 - LearningRate: 1451.9614591771106
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04349899020991987, 0.07023795083045269, -0.0015563068847019822)
# Offset in voxels (X, Y, Z): (-0.338445105242566, -0.13888744864034624, 0.5883862651524032)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00033395856411468344 - LearningRate: 337.7201398420092
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.04825649810846662, 0.09828083751589521, -0.0019527586786128174)
# Offset in voxels (X, Y, Z): (-0.4716550943775521, -0.1575755776120498, 0.6453500409107095)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00029759021159872647 - LearningRate: 995.3887306157151
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.055280048206427304, 0.0794044032100952, -0.002391269716813852)
# Offset in voxels (X, Y, Z): (-0.3964692530632157, -0.1833383299940982, 0.8156754756675783)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0002783186651129883 - LearningRate: 348.4225573836067
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.05775215361994506, 0.0949197169466306, -0.002678473205229934)
# Offset in voxels (X, Y, Z): (-0.47250900625665443, -0.19552784924591568, 0.8521626765534096)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.00026646994131507355 - LearningRate: 978.9315222637092
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06035611126846764, 0.08207420332241787, -0.003098546556665944)
# Offset in voxels (X, Y, Z): (-0.42634573172501267, -0.21169825268354422, 0.9555938994988081)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00025938732216882864 - LearningRate: 350.62125120611273
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.061421214900810484, 0.09125405665997048, -0.003327864929456094)
# Offset in voxels (X, Y, Z): (-0.473472420597753, -0.2199593975343339, 0.97838018660001)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.00025488013241916106 - LearningRate: 992.1564802342839
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06144947538089897, 0.08208127509622953, -0.0037483679873314096)
# Offset in voxels (X, Y, Z): (-0.44506767669020536, -0.2307779134526429, 1.043787403870996)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.0002520979338982196 - LearningRate: 352.2767376888428
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.061617855918939264, 0.08747521797103346, -0.0039451996671936995)
# Offset in voxels (X, Y, Z): (-0.4748665681569964, -0.23623353920315338, 1.057922189347366)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.00025034363540677487 - LearningRate: 966.8464450812364
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.06024526486633397, 0.08079981976519614, -0.004349245791738956)
# Offset in voxels (X, Y, Z): (-0.45777593042283604, -0.24323998738902328, 1.0974357410912252)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.321184158325195 s
# Initial cost function: 6.89838615434094e-310
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7969.524012471302, 7960.433662721125, 12656.2133965708, 1.0000000000038654, 0.999999999998181, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.00047595230853000664 - LearningRate: 79.98890697279317
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.053719862678944706, 0.0847372082394636, -0.004905701347574207)
# Offset in voxels (X, Y, Z): (-0.4796372374232779, -0.20823566219210088, 1.1085128576573264)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.00046054472293817326 - LearningRate: 19.810916386639626
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.054286618339821485, 0.08436433231998401, -0.004928544279588245)
# Offset in voxels (X, Y, Z): (-0.47891202976309044, -0.20979929366207997, 1.1091471323364839)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 1.1026942729949951 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32864.8161475273, 32824.72645924476, 51259.067698863706, 1.0000000000095497, 1.0000000000095497, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0009556783949476531 - LearningRate: 121.69148672102177
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.041098720854884904, 0.08354873454928047, -0.005651430722017697)
# Offset in voxels (X, Y, Z): (-0.955033006621911, -0.27582676328375466, 2.2707589532682713)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0008355696327008169 - LearningRate: 152.48701791411685
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.0453789511948507, 0.0828233417022623, -0.0057638182879153664)
# Offset in voxels (X, Y, Z): (-0.9566430320539047, -0.2972182864481763, 2.2887419340050243)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0008334367716842057 - LearningRate: 755.9433392477978
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.052908676777993977, 0.07941145274464234, -0.00679889750191582)
# Offset in voxels (X, Y, Z): (-0.9636672808370259, -0.2742998196978942, 2.400285459039154)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0008202917056867099 - LearningRate: 80.28468857780707
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.056136912003550254, 0.0790599907110246, -0.006793476723739262)
# Offset in voxels (X, Y, Z): (-0.9642504986083371, -0.29695841178301047, 2.40286581822293)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# ...
# Offset in voxels (X, Y, Z): (-2.2521229376705114, -9.296021047519913, 12.065139286553707)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 420.0, 0.0)
#
#
# Computed transform, took 945.8117027282715 s
# Applying transform to volume, took 7.111435174942017 s
# Transformation of type: <class 'SimpleITK.SimpleITK.Euler3DTransform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (0.10947834646931685, 0.05280805967364667, -0.014685023605789212)
# Offset in voxels (X, Y, Z): (-2.2521229376705114, -9.296021047519913, 12.065139286553707)
# Center of rotation (X, Y, Z, A): (636.0, 636.0, 440.0, 0.0)
# 	 This took: 1210.753029346466 s
# /global/homes/e/eboigne/cfs_als/2022_wood/run24_birch_lowHeat_test2/16a/
#
#
# ============ NEW SCAN ============
#
# Processing scan: 20220501_182201_24_SampleB2_2xLens_16_1313.h5
# Importing data:
# This took 28.12577486038208 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 0
# 	Level: 0
# 	Scales: (7802.434979383447, 7802.43497938349, 12640.394662851351, 1.0000000000010232, 1.0000000000010232, 0.9999999999996021)
# Fixed parameters (image center): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 0 - Cost function: 0.002664328791187299 - LearningRate: 286.26336606731763
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.21331810619997946, 0.06075113073888186, 0.0073623224692932875)
# Offset in voxels (X, Y, Z): (-0.29457598516444966, -0.9826920123234101, -0.05154291401461534)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0005400284740520892 - LearningRate: 1419.1298892809496
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.20995319560796988, 0.05546391600823316, 0.005207234866756656)
# Offset in voxels (X, Y, Z): (-0.2749778673883317, -0.9254910599749364, 0.5644185706829399)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 2 - Cost function: 0.00037917471881874305 - LearningRate: 337.2147799165534
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.24687660877026002, 0.06387865379349422, 0.0062971798908040425)
# Offset in voxels (X, Y, Z): (-0.3190268514655938, -1.0968797378701356, 0.6108612051357776)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 3 - Cost function: 0.00032007297697664284 - LearningRate: 1011.6443197240728
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.23225297319596178, 0.05800602444384148, 0.005038219537685346)
# Offset in voxels (X, Y, Z): (-0.30064023100943327, -1.035758826271481, 0.8398949001206106)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 4 - Cost function: 0.0002922408751240269 - LearningRate: 343.94558755731856
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.2527935488773699, 0.06271334282352067, 0.005622556746472563)
# Offset in voxels (X, Y, Z): (-0.3274266472262626, -1.1363826472479865, 0.870168039828163)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 5 - Cost function: 0.0002723814397197796 - LearningRate: 955.1670219325987
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.24115828602162406, 0.058126716478992105, 0.004778710045002563)
# Offset in voxels (X, Y, Z): (-0.3165777793049048, -1.1012921231308908, 1.0038659633429108)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 6 - Cost function: 0.00026182506926457317 - LearningRate: 349.8756828742487
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.25228132051611624, 0.06058942327544446, 0.00507905203727606)
# Offset in voxels (X, Y, Z): (-0.33295173272745293, -1.161494528182513, 1.0240157009189716)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 7 - Cost function: 0.0002549491305079685 - LearningRate: 990.0467380284941
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.24196088317229844, 0.05656885089833927, 0.004431749961722459)
# Offset in voxels (X, Y, Z): (-0.3262683081985111, -1.1403873497102153, 1.1112628916560174)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 8 - Cost function: 0.0002505308277817378 - LearningRate: 336.60269758969724
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.24805297290946116, 0.057816365916014044, 0.004587493763463716)
# Offset in voxels (X, Y, Z): (-0.3367349875457634, -1.1783320624336335, 1.1228501157908166)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
# Iteration: 9 - Cost function: 0.000247852220889134 - LearningRate: 1234.906778126837
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.23790980896947284, 0.05376536209988841, 0.003994556658346816)
# Offset in voxels (X, Y, Z): (-0.3334755551820029, -1.1685551950059656, 1.1896456426463098)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 38.5, 0.0)
#
#
# Computed transform, took 4.287808895111084 s
# Initial cost function: 1.63e-322
#
# 	Offset iteration number: 10
# 	Level: 0
# 	Scales: (7966.48044451449, 7960.433662721158, 12673.041411506198, 1.0000000000038654, 1.0000000000038654, 1.0000000000010232)
# Fixed parameters (image center): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 0 - Cost function: 0.0005231557919445326 - LearningRate: 86.4745319157972
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.23418505276941232, 0.05588350318526767, 0.0036741631232517303)
# Offset in voxels (X, Y, Z): (-0.3470604510188582, -1.1535914971646182, 1.1974608652002336)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
# Iteration: 1 - Cost function: 0.0005192170387988518 - LearningRate: 39.773099517857645
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.23448036931199961, 0.05521134639889963, 0.0036425674427045707)
# Offset in voxels (X, Y, Z): (-0.3457518993096289, -1.1561404803948274, 1.1990632900089293)
# Center of rotation (X, Y, Z, A): (79.5, 79.5, 40.5, 0.0)
#
#
# Computed transform, took 0.9860193729400635 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 20
# 	Level: 0
# 	Scales: (32850.9537447912, 32824.726459245394, 51323.60276010428, 1.0000000000095497, 0.999999999998181, 1.0000000000038654)
# Fixed parameters (image center): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0010867337015651021 - LearningRate: 119.61837287106331
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.21931091739541825, 0.05438851898466415, 0.002963784031936595)
# Offset in voxels (X, Y, Z): (-0.6873100418986682, -2.1654300242353166, 2.4510143238437205)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0009576560105151302 - LearningRate: 148.97090518951137
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22153628443857495, 0.05381542429114065, 0.0029113766685380034)
# Offset in voxels (X, Y, Z): (-0.6887668633355227, -2.1871936188165697, 2.4681993138241367)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0009559452706280884 - LearningRate: 738.5124652588595
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22017999055296342, 0.0511176528422801, 0.002218180836038798)
# Offset in voxels (X, Y, Z): (-0.6948761229935916, -2.177355555773433, 2.5740966961825054)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 3 - Cost function: 0.0009436827405228269 - LearningRate: 75.5984787946015
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22208253438523023, 0.05085384080737093, 0.0022417882033825306)
# Offset in voxels (X, Y, Z): (-0.6953758133955606, -2.1970940534107757, 2.5771085773824733)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 4 - Cost function: 0.0009417762458646903 - LearningRate: 99.64690503507134
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22287382317884588, 0.0505334727489692, 0.0022092793561706123)
# Offset in voxels (X, Y, Z): (-0.6960422995287546, -2.206597350838399, 2.5845905837294167)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 5 - Cost function: 0.0009414708651394188 - LearningRate: 493.9923094328308
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22325604949733052, 0.04900578443917868, 0.001924195246363583)
# Offset in voxels (X, Y, Z): (-0.6991858862250925, -2.22001913969072, 2.6276128940051837)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 6 - Cost function: 0.0009381872353494223 - LearningRate: 1088.5345151226716
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.21974808208738672, 0.045886725750764606, 0.0012414428082528565)
# Offset in voxels (X, Y, Z): (-0.7045946856771804, -2.213281441078746, 2.7114986516090545)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 7 - Cost function: 0.0009331157370257802 - LearningRate: 65.48620837364606
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.22102847213681565, 0.045735584983986347, 0.001268043423834772)
# Offset in voxels (X, Y, Z): (-0.7050685662066793, -2.227870902133765, 2.71100840643247)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
# Iteration: 8 - Cost function: 0.0009322364459866806 - LearningRate: 0.8445110751180955
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.2210339373826664, 0.04573363431347782, 0.0012679763691971339)
# Offset in voxels (X, Y, Z): (-0.7050731437535045, -2.227952401438538, 2.711025879737146)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 85.0, 0.0)
#
#
# Computed transform, took 17.67096471786499 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 30
# 	Level: 0
# 	Scales: (33722.71834783518, 33699.7191676038, 51306.37035628119, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0009339511533713391 - LearningRate: 272.3894719912196
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.21846032278876104, 0.044263185505748634, 0.001105910724146157)
# Offset in voxels (X, Y, Z): (-0.6980663451932869, -2.2127026936088754, 2.7261949895598816)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0009317473559865227 - LearningRate: 27.883388149694994
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.21870958762343432, 0.044332387155302834, 0.0011034816279500272)
# Offset in voxels (X, Y, Z): (-0.6993719108871796, -2.215854275262187, 2.726465144586408)
# Center of rotation (X, Y, Z, A): (159.0, 159.0, 90.0, 0.0)
#
#
# Computed transform, took 4.827010154724121 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 40
# 	Level: 0
# 	Scales: (139234.26129930734, 139139.84049553436, 206485.13167474163, 0.999999999998181, 0.999999999998181, 0.999999999998181)
# Fixed parameters (image center): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0016464393853978252 - LearningRate: 198.17196856147055
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.20456350907436563, 0.04470418680599057, 0.0006262818247856401)
# Offset in voxels (X, Y, Z): (-1.4050425369866058, -4.18613476563832, 5.522966523638059)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 1 - Cost function: 0.001439781116071479 - LearningRate: 140.6538923101191
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.2048735614483647, 0.0446018419483308, 0.0006267707268015408)
# Offset in voxels (X, Y, Z): (-1.4045947196546982, -4.198781929635971, 5.529381121137078)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 2 - Cost function: 0.0014394236664531576 - LearningRate: 697.281476715587
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.20429542699612258, 0.04430355510173299, 0.0005606336223000135)
# Offset in voxels (X, Y, Z): (-1.405589675256426, -4.223513464651091, 5.568419686172346)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 3 - Cost function: 0.001437942479380981 - LearningRate: 609.3092373201503
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.2014732354110201, 0.04427277616285936, 0.000437488627060198)
# Offset in voxels (X, Y, Z): (-1.4094612009438383, -4.203994541268079, 5.606211628591672)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 4 - Cost function: 0.001434874551307149 - LearningRate: 104.7053511414529
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.20189415091795374, 0.04418519106774666, 0.0004485176643836107)
# Offset in voxels (X, Y, Z): (-1.408712616158988, -4.217021993281289, 5.6082797909200925)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
# Iteration: 5 - Cost function: 0.00143440993576663 - LearningRate: 80.67650264827881
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.2019421275082286, 0.04414470298432896, 0.0004478396080043119)
# Offset in voxels (X, Y, Z): (-1.4085617856098132, -4.2220825953508765, 5.610916704707853)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 190.0, 0.0)
#
#
# Computed transform, took 72.11598134040833 s
# Initial cost function: 0.0
#
# 	Offset iteration number: 50
# 	Level: 0
# 	Scales: (143138.7729556765, 143039.8079956383, 206431.53688619134, 1.0000000000209184, 0.999999999998181, 1.0000000000095497)
# Fixed parameters (image center): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 0 - Cost function: 0.0024070088999241265 - LearningRate: 115.4499233297187
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.1937276129384884, 0.043698518660573005, 0.0002266627169137994)
# Offset in voxels (X, Y, Z): (-1.3966803544296669, -4.091588295673471, 5.651168900190855)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
# Iteration: 1 - Cost function: 0.0022603299685788197 - LearningRate: 13.473899542732102
# Transformation of type: <class 'SimpleITK.SimpleITK.Transform'>
# 	 Registration parameters:
# Euler angle in degrees (X, Y, Z): (-0.19383893220131262, 0.043724425358087335, 0.00022924617131170352)
# Offset in voxels (X, Y, Z): (-1.396753400798794, -4.095351083869463, 5.65147710124979)
# Center of rotation (X, Y, Z, A): (318.0, 318.0, 200.0, 0.0)
#
#
# Computed transform, took 28.682932376861572 s
# Initial cost function: 4.6876744136578e-310

# %%
print(time.time())

# %%
# # Quickly check registration in Fiji (only makes sense if #tiles > 1)
# # Select folder 'run23_G_flameNoKr_y04', and check results with Fiji.
# # Then: Adjust the integer list in diffs: choose good scans only to average.
#
# Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
# path_folder = askdirectory(initialdir=path_save) # show an "Open" dialog box and return the path to the selected file
#
# bin_factor = 4
# ind_slices = np.arange(50, 520-50, 100)
# ind_slices = np.append(ind_slices, 510)
# ind_slices = ind_slices//bin_factor
# # ind_slices = np.linspace(30, 45, 16).astype('int')
# print(ind_slices)
#
# slices = File.File(path_folder+'/00/').read(ind_slices)
# slices_avg = np.copy(slices)
# File.File(path_folder+'/FijiCheck/00/').saveTiffStack(slices, '', ind_slices)
#
# list_dir = [e for e in os.listdir(path_folder) if e != 'FijiCheck']
# for dir in list_dir[1:]:
#     print(dir)
#     slices = File.File(path_folder+'/'+dir+'/b_movingRegisteredToStatic/').read(ind_slices)
#     slices_avg += slices
#     File.File(path_folder+'/FijiCheck/'+dir+'/').saveTiffStack(slices, '', ind_slices)
#
# slices_avg /= len(list_dir)
# File.File(path_folder+'/FijiCheck/avg/').saveTiffStack(slices_avg, '', ind_slices)
#
